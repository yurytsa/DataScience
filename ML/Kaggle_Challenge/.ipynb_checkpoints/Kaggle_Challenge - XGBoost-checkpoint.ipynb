# %% [markdown]
# # Regression Models in R (tips)

# %%
if(!exists("Table1", mode="function")) source("mechkar.R")

# %%
library(readr)
library(dplyr)
library(ggplot2)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.0.2"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'ggplot2' was built under R version 4.0.2"

# %%
df <- read.csv("train.csv")
head(df)
dim(df)
# Out:
#   id season mnth holiday weekday workingday weathersit temp     atemp
# 1 1  1      1    0       6       0          2          0.344167 0.363625
# 2 2  1      1    0       0       0          2          0.363478 0.353739
# 3 3  1      1    0       1       1          1          0.196364 0.189405
# 4 4  1      1    0       2       1          1          0.200000 0.212122
# 5 5  1      1    0       3       1          1          0.226957 0.229270
# 6 6  1      1    0       4       1          1          0.204348 0.233209
#   hum      windspeed cnt
# 1 0.805833 0.1604460  985
# 2 0.696087 0.2485390  801
# 3 0.437273 0.2483090 1349
# 4 0.590435 0.1602960 1562
# 5 0.436957 0.1869000 1600
# 6 0.518261 0.0895652 1606
# [1] 365  12

# %% [markdown]
# Data Set Information:
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
#
# Attribute Information:
#
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# - instant: record index
# - season : season (1:winter, 2:spring, 3:summer, 4:fall)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not (extracted from [Web Link])
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# + weathersit :
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)
# - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# # EDA

# %%
df$holiday <- as.factor(df$holiday)
df$season <- as.factor(df$season)
df$mnth <- as.factor(df$mnth)
df$workingday <- as.factor(df$workingday)
df$weathersit <- as.factor(df$weathersit)
df$weekday <- as.factor(df$weekday)
summary(df)
# Out:
#        id      season      mnth     holiday weekday workingday weathersit
#  Min.   :  1   1:90   1      : 31   0:355   0:52    0:115      1:226
#  1st Qu.: 92   2:92   3      : 31   1: 10   1:52    1:250      2:124
#  Median :183   3:94   5      : 31           2:52               3: 15
#  Mean   :183   4:89   7      : 31           3:52
#  3rd Qu.:274          8      : 31           4:52
#  Max.   :365          10     : 31           5:52
#                       (Other):179           6:53
#       temp             atemp              hum           windspeed
#  Min.   :0.05913   Min.   :0.07907   Min.   :0.0000   Min.   :0.02239
#  1st Qu.:0.32500   1st Qu.:0.32195   1st Qu.:0.5383   1st Qu.:0.13558
#  Median :0.47917   Median :0.47285   Median :0.6475   Median :0.18690
#  Mean   :0.48666   Mean   :0.46684   Mean   :0.6437   Mean   :0.19140
#  3rd Qu.:0.65667   3rd Qu.:0.61238   3rd Qu.:0.7421   3rd Qu.:0.23508
#  Max.   :0.84917   Max.   :0.84090   Max.   :0.9725   Max.   :0.50746
#
#       cnt
#  Min.   : 431
#  1st Qu.:2132
#  Median :3740
#  Mean   :3406
#  3rd Qu.:4586
#  Max.   :6043

# %% [markdown]
# # DATASET PARTITION

# %%
tab1 <- train_test(data=df, train_name="train", test_name="test", prop=0.7, seed=5, tableone=TRUE)
tab1
# Out:
# Dataset partitioned into:
#
#  + Train dataset: train
#
#  + Test dataset: test
#
# Warning message in Table1(data = df, y = "traintest_ind_", messages = FALSE):
# "The following variables have unique values and will not be included in the analysis: "
#   |======================================================================| 100%
# Warning message:
# "The `x` argument of `as_tibble.matrix()` must have unique column names if `.name_repair` is omitted as of tibble 2.0.0.
# Using compatibility `.name_repair`.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated."
#   |===========================                                           |  38%
# Warning message in stats::chisq.test(data[[v]], data[[y]]):
# "Chi-squared approximation may be incorrect"
#   |=================================================================     |  92%
#
#
# You got a perfectly balanced training and test datasets
#    V1             V2           Pop
# 1  Individuals    n            365
# 2  id             Mean (SD)    183.0 (105.5)
# 3  id             Median (IQR) 183.0 (92.0-274.0)
# 4  season         1            90 (24.7%)
# 5  season         2            92 (25.2%)
# 6  season         3            94 (25.8%)
# 7  season         4            89 (24.4%)
# 8  mnth           1            31 (8.5%)
# 9  mnth           2            28 (7.7%)
# 10 mnth           3            31 (8.5%)
# 11 mnth           4            30 (8.2%)
# 12 mnth           5            31 (8.5%)
# 13 mnth           6            30 (8.2%)
# 14 mnth           7            31 (8.5%)
# 15 mnth           8            31 (8.5%)
# 16 mnth           9            30 (8.2%)
# 17 mnth           10           31 (8.5%)
# 18 mnth           11           30 (8.2%)
# 19 mnth           12           31 (8.5%)
# 20 holiday        1            10 (2.7%)
# 21 weekday        0            52 (14.2%)
# 22 weekday        1            52 (14.2%)
# 23 weekday        2            52 (14.2%)
# 24 weekday        3            52 (14.2%)
# 25 weekday        4            52 (14.2%)
# 26 weekday        5            52 (14.2%)
# 27 weekday        6            53 (14.5%)
# 28 workingday     1            250 (68.5%)
# 29 weathersit     1            226 (61.9%)
# 30 weathersit     2            124 (34.0%)
# 31 weathersit     3            15 (4.1%)
# 32 temp           Mean (SD)    0.5 (0.2)
# 33 temp           Median (IQR) 0.5 (0.3-0.7)
# 34 atemp          Mean (SD)    0.5 (0.2)
# 35 atemp          Median (IQR) 0.5 (0.3-0.6)
# 36 hum            Mean (SD)    0.6 (0.1)
# 37 hum            Median (IQR) 0.6 (0.5-0.7)
# 38 windspeed      Mean (SD)    0.2 (0.1)
# 39 windspeed      Median (IQR) 0.2 (0.1-0.2)
# 40 cnt            Mean (SD)    3,405.8 (1,378.8)
# 41 cnt            Median (IQR) 3,740.0 (2,132.0-4,586.0)
# 42 traintest_ind_ Mean (SD)    1.3 (0.5)
# 43 traintest_ind_ Median (IQR) 1.0 (1.0-2.0)
#    1                         2                         pval
# 1  255                       110                       NA
# 2  183.7 (105.0)             181.4 (107.2)             NA
# 3  181.0 (92.5-272.5)        184.5 (88.0-277.0)        0.854
# 4  62 (24.3%)                28 (25.5%)                NA
# 5  67 (26.3%)                25 (22.7%)                0.914
# 6  65 (25.5%)                29 (26.4%)                NA
# 7  61 (23.9%)                28 (25.5%)                NA
# 8  20 (7.8%)                 11 (10.0%)                NA
# 9  18 (7.1%)                 10 (9.1%)                 0.841
# 10 24 (9.4%)                 7 (6.4%)                  NA
# 11 20 (7.8%)                 10 (9.1%)                 NA
# 12 23 (9.0%)                 8 (7.3%)                  NA
# 13 23 (9.0%)                 7 (6.4%)                  NA
# 14 20 (7.8%)                 11 (10.0%)                NA
# 15 24 (9.4%)                 7 (6.4%)                  NA
# 16 20 (7.8%)                 10 (9.1%)                 NA
# 17 21 (8.2%)                 10 (9.1%)                 NA
# 18 18 (7.1%)                 12 (10.9%)                NA
# 19 24 (9.4%)                 7 (6.4%)                  NA
# 20 5 (2.0%)                  5 (4.5%)                  0.166
# 21 36 (14.1%)                16 (14.5%)                NA
# 22 34 (13.3%)                18 (16.4%)                0.931
# 23 36 (14.1%)                16 (14.5%)                NA
# 24 34 (13.3%)                18 (16.4%)                NA
# 25 38 (14.9%)                14 (12.7%)                NA
# 26 38 (14.9%)                14 (12.7%)                NA
# 27 39 (15.3%)                14 (12.7%)                NA
# 28 175 (68.6%)               75 (68.2%)                1
# 29 153 (60.0%)               73 (66.4%)                NA
# 30 93 (36.5%)                31 (28.2%)                0.253
# 31 9 (3.5%)                  6 (5.5%)                  NA
# 32 0.5 (0.2)                 0.5 (0.2)                 NA
# 33 0.5 (0.3-0.7)             0.5 (0.3-0.7)             0.633
# 34 0.5 (0.2)                 0.5 (0.2)                 NA
# 35 0.5 (0.3-0.6)             0.5 (0.3-0.6)             0.681
# 36 0.6 (0.2)                 0.7 (0.1)                 NA
# 37 0.6 (0.5-0.7)             0.6 (0.5-0.7)             0.53
# 38 0.2 (0.1)                 0.2 (0.1)                 NA
# 39 0.2 (0.1-0.2)             0.2 (0.1-0.2)             0.704
# 40 3,443.5 (1,363.5)         3,318.2 (1,415.8)         NA
# 41 3,750.0 (2,185.5-4,591.0) 3,577.5 (1,916.5-4,546.2) 0.426
# 42 NA                        NA                        NA
# 43 NA                        NA                        0

# %%
### Table of resulting errors
### Name, Model, RMSE, RMSLE
err_res <- NULL

# %%
### The error we will use is the RMSE and RMSLE
rmse <- function(y,y_hat) {
    err <- sqrt(sum((y_hat-y)^2,na.rm=T)/length(y))
    return(err)
}

rmsle <- function(y,y_hat) {
    err <- sqrt(sum((log(y_hat+1)-log(y+1))^2,na.rm=T)/length(y))
    return(err)
}

# %% [markdown]
# ## XGBoost

# %%
#install.packages("xgboost")
library(xgboost)

# %%
cnames = names(train)
cnames <- cnames[c(2:11)]

variables_comb <- list()

# length(combn(cnames,3))
# combn(cnames,3)

counter <-  0
for(i in 1:10) {
    curr_combs <- combn(cnames,i)
    for(j in 1:(length(curr_combs)/i)){
        counter <- counter + 1
        curr_comb <- data.frame(curr_combs[,j])
        variables_comb[counter] <- curr_comb
    }
}

# %%
# install.packages("svMisc")
require(svMisc)
# Out:
# Loading required package: svMisc
#
# Warning message:
# "package 'svMisc' was built under R version 4.0.3"
#
# Attaching package: 'svMisc'
#
#
# The following object is masked from 'package:utils':
#
#     ?

# %%
err_res <- NULL
counter <- 0
for(curr_vars in variables_comb){
    
    counter <- counter + 1
    progress(counter * 100 / 1023)
    
    outcome <- "cnt"
    variables <- curr_vars
    f <- as.formula( paste(outcome,  paste(variables, collapse = " + "), sep = " ~ "))
    
    train1 <- Matrix::sparse.model.matrix(f, data = train)
    test1 <- Matrix::sparse.model.matrix(f, data = test)
    
    #X_train <- xgb.DMatrix(train1)
    X_train <- train1
    y_train <- train$cnt
    mod7 <- xgboost(data=X_train,label=y_train, nrounds=1000,print_every_n = 100, early_stopping_rounds=10)
    #X_test <- xgb.DMatrix(test1)
    X_test <- test1
    y_test <- test$cnt

    pred7 <- predict(mod7,newdata=X_test)
    rmse(y_test,pred7)
    rmsle(y_test,pred7)
    err_res <- rbind(err_res, data.frame(Name="XGBoost", Model="mod7", 
                                         RMSE=rmse(test$cnt,pred7), 
                                         RMSLE=rmsle(test$cnt,pred7)))
}
# Out:
# Progress:   0%  [1]	train-rmse:2681.926025
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [28]	train-rmse:877.957703
#
# Progress:   0%  [1]	train-rmse:2724.260498
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:723.988586
# [201]	train-rmse:723.285156
# Stopping. Best iteration:
# [246]	train-rmse:723.283264
#
# Progress:   0%  [1]	train-rmse:2771.290283
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [26]	train-rmse:1360.755615
#
# Progress:   0%  [1]	train-rmse:2771.290283
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [26]	train-rmse:1357.937866
#
# Progress:   0%  [1]	train-rmse:2771.290283
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [27]	train-rmse:1360.642822
#
# Progress:   0%  [1]	train-rmse:2756.168701
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [27]	train-rmse:1280.976807
#
# Progress:   0%  [1]	train-rmse:2665.112305
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:305.812073
# [201]	train-rmse:297.217712
# [301]	train-rmse:296.656036
# [401]	train-rmse:296.617218
# [501]	train-rmse:296.614227
# Stopping. Best iteration:
# [550]	train-rmse:296.613922
#
# Progress:   0%  [1]	train-rmse:2665.739258
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:155.574875
# [201]	train-rmse:66.071312
# [301]	train-rmse:48.158501
# [401]	train-rmse:45.170399
# [501]	train-rmse:44.756081
# [601]	train-rmse:44.696728
# [701]	train-rmse:44.687023
# [801]	train-rmse:44.685375
# [901]	train-rmse:44.685131
# Stopping. Best iteration:
# [923]	train-rmse:44.685108
#
# Progress:   0%  [1]	train-rmse:2761.689453
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:428.461243
# [201]	train-rmse:378.639679
# [301]	train-rmse:374.924194
# [401]	train-rmse:374.632538
# [501]	train-rmse:374.606445
# [601]	train-rmse:374.603638
# Stopping. Best iteration:
# [640]	train-rmse:374.603363
#
# Progress:   0%  [1]	train-rmse:2757.628662
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:357.757935
# [201]	train-rmse:279.733429
# [301]	train-rmse:272.846954
# [401]	train-rmse:272.055389
# [501]	train-rmse:271.962738
# [601]	train-rmse:271.949738
# [701]	train-rmse:271.947876
# Stopping. Best iteration:
# [735]	train-rmse:271.947693
#
# Progress:   0%  [1]	train-rmse:2667.567139
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [32]	train-rmse:687.434082
#
# Progress:   0%  [1]	train-rmse:2681.926025
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [47]	train-rmse:872.081421
#
# Progress:   0%  [1]	train-rmse:2681.926270
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [85]	train-rmse:859.479614
#
# Progress:   0%  [1]	train-rmse:2681.926025
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [32]	train-rmse:867.474426
#
# Progress:   0%  [1]	train-rmse:2672.685547
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [32]	train-rmse:753.005737
#
# Progress:   0%  [1]	train-rmse:2650.692871
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:231.928726
# [201]	train-rmse:222.457260
# [301]	train-rmse:222.054810
# [401]	train-rmse:222.024399
# [501]	train-rmse:222.022568
# Stopping. Best iteration:
# [504]	train-rmse:222.022552
#
# Progress:   0%  [1]	train-rmse:2650.486572
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:78.817268
# [201]	train-rmse:26.051004
# [301]	train-rmse:16.416451
# [401]	train-rmse:15.206105
# [501]	train-rmse:15.030336
# [601]	train-rmse:15.013584
# [701]	train-rmse:15.011473
# [801]	train-rmse:15.011213
# Stopping. Best iteration:
# [873]	train-rmse:15.011181
#
# Progress:   0%  [1]	train-rmse:2671.583252
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:170.885788
# [201]	train-rmse:142.346359
# [301]	train-rmse:140.610626
# [401]	train-rmse:140.502121
# [501]	train-rmse:140.495255
# [601]	train-rmse:140.494568
# Stopping. Best iteration:
# [604]	train-rmse:140.494553
#
# Progress:   0%  [1]	train-rmse:2678.151123
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:185.706665
# [201]	train-rmse:171.181656
# [301]	train-rmse:170.780319
# [401]	train-rmse:170.762039
# [501]	train-rmse:170.760666
# Stopping. Best iteration:
# [498]	train-rmse:170.760666
#
# Progress:   0%  [1]	train-rmse:2724.260498
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:711.017273
# [201]	train-rmse:710.256104
# Stopping. Best iteration:
# [246]	train-rmse:710.254028
#
# Progress:   0%  [1]	train-rmse:2724.260498
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:609.912292
# [201]	train-rmse:605.897888
# [301]	train-rmse:605.572815
# [401]	train-rmse:605.531738
# [501]	train-rmse:605.520691
# [601]	train-rmse:605.516357
# [701]	train-rmse:605.514771
# Stopping. Best iteration:
# [753]	train-rmse:605.514343
#
# Progress:   0%  [1]	train-rmse:2724.260498
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:685.662109
# [201]	train-rmse:684.490295
# Stopping. Best iteration:
# [278]	train-rmse:684.481323
#
# Progress:   0%  [1]	train-rmse:2709.411377
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:577.171204
# [201]	train-rmse:572.599731
# [301]	train-rmse:572.301697
# [401]	train-rmse:572.282349
# Stopping. Best iteration:
# [451]	train-rmse:572.281311
#
# Progress:   0%  [1]	train-rmse:2660.221680
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:81.979111
# [201]	train-rmse:55.823856
# [301]	train-rmse:55.108101
# [401]	train-rmse:55.076668
# [501]	train-rmse:55.075218
# Stopping. Best iteration:
# [554]	train-rmse:55.075150
#
# Progress:   0%  [1]	train-rmse:2662.524902
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:72.956932
# [201]	train-rmse:20.053299
# [301]	train-rmse:15.264087
# [401]	train-rmse:15.026615
# [501]	train-rmse:15.012240
# [601]	train-rmse:15.011253
# [701]	train-rmse:15.011176
# Stopping. Best iteration:
# [717]	train-rmse:15.011174
#
# Progress:   0%  [1]	train-rmse:2713.998047
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:72.121178
# [201]	train-rmse:9.924691
# [301]	train-rmse:6.044199
# [401]	train-rmse:5.935884
# [501]	train-rmse:5.933662
# Stopping. Best iteration:
# [566]	train-rmse:5.933622
#
# Progress:   0%  [1]	train-rmse:2718.726562
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:70.815651
# [201]	train-rmse:6.983964
# [301]	train-rmse:0.722744
# [401]	train-rmse:0.090763
# [501]	train-rmse:0.012824
# [601]	train-rmse:0.002600
# Stopping. Best iteration:
# [666]	train-rmse:0.002052
#
# Progress:   0%  [1]	train-rmse:2771.290283
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [29]	train-rmse:1357.606323
#
# Progress:   0%  [1]	train-rmse:2771.290283
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [27]	train-rmse:1360.588745
#
# Progress:   0%  [1]	train-rmse:2756.168701
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [43]	train-rmse:1277.937378
#
# Progress:   0%  [1]	train-rmse:2664.688965
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:299.125641
# [201]	train-rmse:286.588104
# [301]	train-rmse:286.004700
# [401]	train-rmse:285.965149
# [501]	train-rmse:285.962189
# Stopping. Best iteration:
# [521]	train-rmse:285.962067
#
# Progress:   0%  [1]	train-rmse:2665.574463
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:546.973450
# [201]	train-rmse:546.709045
# [301]	train-rmse:546.692383
# [401]	train-rmse:546.689941
# Stopping. Best iteration:
# [396]	train-rmse:546.689941
#
# Progress:   0%  [1]	train-rmse:2667.567139
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [68]	train-rmse:646.401855
#
# Progress:   0%  [1]	train-rmse:2660.872314
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [90]	train-rmse:526.283386
#
# Progress:   0%  [1]	train-rmse:2650.693115
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:72.069466
# [201]	train-rmse:52.750156
# [301]	train-rmse:52.235729
# [401]	train-rmse:52.210159
# [501]	train-rmse:52.209126
# Stopping. Best iteration:
# [544]	train-rmse:52.209091
#
# Progress:   0%  [1]	train-rmse:2650.486572
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:63.616058
# [201]	train-rmse:18.464342
# [301]	train-rmse:15.199698
# [401]	train-rmse:15.020610
# [501]	train-rmse:15.011678
# [601]	train-rmse:15.011206
# Stopping. Best iteration:
# [670]	train-rmse:15.011175
#
# Progress:   0%  [1]	train-rmse:2658.216797
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:31.163086
# [201]	train-rmse:6.759878
# [301]	train-rmse:5.949131
# [401]	train-rmse:5.934018
# [501]	train-rmse:5.933629
# Stopping. Best iteration:
# [535]	train-rmse:5.933621
#
# Progress:   0%  [1]	train-rmse:2663.771729
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:36.704742
# [201]	train-rmse:4.384728
# [301]	train-rmse:0.519064
# [401]	train-rmse:0.074184
# [501]	train-rmse:0.013261
# Stopping. Best iteration:
# [582]	train-rmse:0.003154
#
# Progress:   0%  [1]	train-rmse:2681.926025
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:853.913330
# Stopping. Best iteration:
# [114]	train-rmse:853.913147
#
# Progress:   0%  [1]	train-rmse:2681.926025
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [50]	train-rmse:862.780029
#
# Progress:   0%  [1]	train-rmse:2672.630859
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [42]	train-rmse:746.888062
#
# Progress:   0%  [1]	train-rmse:2650.617920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:216.171478
# [201]	train-rmse:207.967957
# [301]	train-rmse:207.606354
# [401]	train-rmse:207.579910
# [501]	train-rmse:207.577652
# Stopping. Best iteration:
# [538]	train-rmse:207.577530
#
# Progress:   0%  [1]	train-rmse:2650.486572
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:73.461884
# [201]	train-rmse:26.707380
# [301]	train-rmse:16.604044
# [401]	train-rmse:15.171713
# [501]	train-rmse:15.027201
# [601]	train-rmse:15.012778
# [701]	train-rmse:15.011327
# [801]	train-rmse:15.011189
# Stopping. Best iteration:
# [843]	train-rmse:15.011177
#
# Progress:   0%  [1]	train-rmse:2671.500244
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:168.844910
# [201]	train-rmse:141.960449
# [301]	train-rmse:140.569839
# [401]	train-rmse:140.498901
# [501]	train-rmse:140.494797
# Stopping. Best iteration:
# [549]	train-rmse:140.494583
#
# Progress:   0%  [1]	train-rmse:2678.151123
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:189.123962
# [201]	train-rmse:171.696198
# [301]	train-rmse:170.801666
# [401]	train-rmse:170.763840
# [501]	train-rmse:170.760849
# Stopping. Best iteration:
# [553]	train-rmse:170.760605
#
# Progress:   0%  [1]	train-rmse:2681.926270
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [49]	train-rmse:853.913147
#
# Progress:   0%  [1]	train-rmse:2672.685547
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:666.112183
# [201]	train-rmse:665.677856
# [301]	train-rmse:665.573059
# [401]	train-rmse:665.548157
# [501]	train-rmse:665.542053
# [601]	train-rmse:665.540527
# Stopping. Best iteration:
# [599]	train-rmse:665.540527
#
# Progress:   0%  [1]	train-rmse:2650.692871
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:41.294209
# [201]	train-rmse:16.078890
# [301]	train-rmse:15.262731
# [401]	train-rmse:15.248864
# [501]	train-rmse:15.248599
# Stopping. Best iteration:
# [515]	train-rmse:15.248596
#
# Progress:   0%  [1]	train-rmse:2650.486572
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:27.645422
# [201]	train-rmse:3.702978
# [301]	train-rmse:0.472836
# [401]	train-rmse:0.072291
# [501]	train-rmse:0.012377
# Stopping. Best iteration:
# [568]	train-rmse:0.003876
#
# Progress:   0%  [1]	train-rmse:2671.005859
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:50.875355
# [201]	train-rmse:16.918036
# [301]	train-rmse:16.171612
# [401]	train-rmse:16.162582
# Stopping. Best iteration:
# [476]	train-rmse:16.162472
#
# Progress:   0%  [1]	train-rmse:2678.151123
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:59.577152
# [201]	train-rmse:8.284838
# [301]	train-rmse:1.158145
# [401]	train-rmse:0.169748
# [501]	train-rmse:0.029480
# [601]	train-rmse:0.005417
# Stopping. Best iteration:
# [629]	train-rmse:0.002851
#
# Progress:   0%  [1]	train-rmse:2672.685547
# Will train until train_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [30]	train-rmse:738.981628
#
# Progress:   0%  [1]	train-rmse:2650.693115
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:203.881317
# [201]	train-rmse:199.249329
# [301]	train-rmse:199.024384
# [401]	train-rmse:199.012665
# Stopping. Best iteration:
# [486]	train-rmse:199.012039
#
# Progress:   0%  [1]	train-rmse:2650.486572
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:60.581787
# [201]	train-rmse:20.969677
# [301]	train-rmse:15.485408
# [401]	train-rmse:15.043143
# [501]	train-rmse:15.013844
# [601]	train-rmse:15.011431
# [701]	train-rmse:15.011191
# Stopping. Best iteration:
# [756]	train-rmse:15.011177
#
# Progress:   0%  [1]	train-rmse:2671.583252
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:75.634659
# [201]	train-rmse:22.225241
# [301]	train-rmse:17.527754
# [401]	train-rmse:17.232122
# [501]	train-rmse:17.218000
# [601]	train-rmse:17.217302
# Stopping. Best iteration:
# [671]	train-rmse:17.217245
# Progress:   0%  [1]	train-rmse:2678.151123
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:134.824966
# [201]	train-rmse:115.216011
# [301]	train-rmse:114.583023
# [401]	train-rmse:114.555313
# [501]	train-rmse:114.553741
# Stopping. Best iteration:
# [524]	train-rmse:114.553711
#
# Progress:   0%  [1]	train-rmse:2644.584717
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:73.751503
# [201]	train-rmse:57.511246
# [301]	train-rmse:56.379059
# [401]	train-rmse:56.311207
# [501]	train-rmse:56.306335
# [601]	train-rmse:56.306004
# Stopping. Best iteration:
# [613]	train-rmse:56.305996
#
# Progress:   0%  [1]	train-rmse:2644.447754
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:54.073376
# [201]	train-rmse:19.379477
# [301]	train-rmse:15.344445
# [401]	train-rmse:15.045087
# [501]	train-rmse:15.014330
# [601]	train-rmse:15.011464
# [701]	train-rmse:15.011199
# Stopping. Best iteration:
# [771]	train-rmse:15.011175
#
# Progress:   0%  [1]	train-rmse:2668.931641
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:82.789856
# [201]	train-rmse:37.441319
# [301]	train-rmse:34.780678
# [401]	train-rmse:34.622623
# [501]	train-rmse:34.616337
# [601]	train-rmse:34.616032
# Stopping. Best iteration:
# [613]	train-rmse:34.616024
#
# Progress:   0%  [1]	train-rmse:2668.634033
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:112.882744
# [201]	train-rmse:98.082077
# [301]	train-rmse:97.831360
# [401]	train-rmse:97.824692
# Stopping. Best iteration:
# [465]	train-rmse:97.824409
#
# Progress:   0%  [1]	train-rmse:2650.354492
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:26.182428
# [201]	train-rmse:3.655457
# [301]	train-rmse:0.618967
# [401]	train-rmse:0.100945
# [501]	train-rmse:0.018550
# [601]	train-rmse:0.003416
# Stopping. Best iteration:
# [623]	train-rmse:0.002371
#
# Progress:   0%  [1]	train-rmse:2643.940186
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:18.959732
# [201]	train-rmse:1.641437
# [301]	train-rmse:0.176696
# [401]	train-rmse:0.013570
# Stopping. Best iteration:
# [490]	train-rmse:0.001908
#
# Progress:   0%  [1]	train-rmse:2648.987061
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:16.754482
# [201]	train-rmse:1.119815
# [301]	train-rmse:0.099971
# [401]	train-rmse:0.009609
# Stopping. Best iteration:
# [464]	train-rmse:0.002170
#
# Progress:   0%  [1]	train-rmse:2642.275635
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:14.423412
# [201]	train-rmse:1.285140
# [301]	train-rmse:0.121004
# [401]	train-rmse:0.013588
# Stopping. Best iteration:
# [480]	train-rmse:0.001948
#
# Progress:   0%  [1]	train-rmse:2648.566650
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:17.380663
# [201]	train-rmse:1.227006
# [301]	train-rmse:0.088071
# [401]	train-rmse:0.005816
# Stopping. Best iteration:
# [442]	train-rmse:0.002001
#
# Progress:   0%  [1]	train-rmse:2671.005615
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:20.939449
# [201]	train-rmse:1.532707
# [301]	train-rmse:0.121919
# [401]	train-rmse:0.008966
# Stopping. Best iteration:
# [461]	train-rmse:0.002201
#
# Progress:   0%  [1]	train-rmse:2724.260742
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:594.029419
# [201]	train-rmse:588.905396
# [301]	train-rmse:588.600220
# [401]	train-rmse:588.556946
# [501]	train-rmse:588.545593
# [601]	train-rmse:588.540771
# [701]	train-rmse:588.538818
# Stopping. Best iteration:
# [760]	train-rmse:588.538208
#
# Progress:   0%  [1]	train-rmse:2724.260498
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:669.803223
# [201]	train-rmse:668.538025
# [301]	train-rmse:668.514771
# Stopping. Best iteration:
# [325]	train-rmse:668.514465
#
# Progress:   0%  [1]	train-rmse:2709.411377
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:565.574585
# [201]	train-rmse:561.210144
# [301]	train-rmse:560.917603
# [401]	train-rmse:560.898438
# Stopping. Best iteration:
# [468]	train-rmse:560.897217
#
# Progress:   0%  [1]	train-rmse:2660.221680
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:80.541878
# [201]	train-rmse:56.360989
# [301]	train-rmse:55.140553
# [401]	train-rmse:55.077904
# [501]	train-rmse:55.075260
# Stopping. Best iteration:
# [551]	train-rmse:55.075161
#
# Progress:   0%  [1]	train-rmse:2662.524902
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:70.340019
# [201]	train-rmse:21.034491
# [301]	train-rmse:15.371257
# [401]	train-rmse:15.037403
# [501]	train-rmse:15.013392
# [601]	train-rmse:15.011317
# [701]	train-rmse:15.011180
# Stopping. Best iteration:
# [728]	train-rmse:15.011175
#
# Progress:   0%  [1]	train-rmse:2713.998047
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:41.414715
# [201]	train-rmse:7.164063
# [301]	train-rmse:1.327878
# [401]	train-rmse:0.279635
# [501]	train-rmse:0.053454
# [601]	train-rmse:0.009229
# Stopping. Best iteration:
# [666]	train-rmse:0.003097
#
# Progress:   0%  [1]	train-rmse:2743.927734
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:182.280716
# [201]	train-rmse:152.201065
# [301]	train-rmse:151.617767
# [401]	train-rmse:151.607468
# Stopping. Best iteration:
# [443]	train-rmse:151.607239
#
# Progress:   0%  [1]	train-rmse:2743.862061
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:165.798660
# [201]	train-rmse:120.969269
# [301]	train-rmse:119.876122
# [401]	train-rmse:119.826591
# [501]	train-rmse:119.823830
# Stopping. Best iteration:
# [547]	train-rmse:119.823715
#
# Progress:   0%  [1]	train-rmse:2664.469727
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:30.345402
# [201]	train-rmse:2.884451
# [301]	train-rmse:0.322693
# [401]	train-rmse:0.037778
# [501]	train-rmse:0.004628
# Stopping. Best iteration:
# [531]	train-rmse:0.002586
#
# Progress:   0%  [1]	train-rmse:2656.319580
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:19.710529
# [201]	train-rmse:2.014193
# [301]	train-rmse:0.149231
# [401]	train-rmse:0.013947
# Stopping. Best iteration:
# [475]	train-rmse:0.002180
#
# Progress:   0%  [1]	train-rmse:2660.793213
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:17.115751
# [201]	train-rmse:1.191126
# [301]	train-rmse:0.072312
# [401]	train-rmse:0.004172
# Stopping. Best iteration:
# [433]	train-rmse:0.001722
#
# Progress:   0%  [1]	train-rmse:2655.667236
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:13.708814
# [201]	train-rmse:0.752635
# [301]	train-rmse:0.046024
# [401]	train-rmse:0.002254
# Stopping. Best iteration:
# [405]	train-rmse:0.002136
#
# Progress:   0%  [1]	train-rmse:2661.622559
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:13.102700
# [201]	train-rmse:0.605013
# [301]	train-rmse:0.036343
# [401]	train-rmse:0.002260
# Stopping. Best iteration:
# [412]	train-rmse:0.001631
#
# Progress:   0%  [1]	train-rmse:2748.830322
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:44.204731
# [201]	train-rmse:2.330439
# [301]	train-rmse:0.131189
# [401]	train-rmse:0.008266
# Stopping. Best iteration:
# [452]	train-rmse:0.002023
#
# Progress:   0%  [1]	train-rmse:2657.189209
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:119.997444
# [201]	train-rmse:97.918335
# [301]	train-rmse:96.787292
# [401]	train-rmse:96.720444
# [501]	train-rmse:96.714027
# [601]	train-rmse:96.713615
# Stopping. Best iteration:
# [595]	train-rmse:96.713615
#
# Progress:   0%  [1]	train-rmse:2658.173828
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:77.940613
# [201]	train-rmse:47.840118
# [301]	train-rmse:44.968872
# [401]	train-rmse:44.715675
# [501]	train-rmse:44.688042
# [601]	train-rmse:44.685368
# [701]	train-rmse:44.685108
# Stopping. Best iteration:
# [709]	train-rmse:44.685101
#
# Progress:   0%  [1]	train-rmse:2741.417969
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:235.002274
# [201]	train-rmse:184.629150
# [301]	train-rmse:181.679047
# [401]	train-rmse:181.517715
# [501]	train-rmse:181.509109
# Stopping. Best iteration:
# [562]	train-rmse:181.508621
#
# Progress:   0%  [1]	train-rmse:2743.862061
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:204.610809
# [201]	train-rmse:126.764069
# [301]	train-rmse:121.954552
# [401]	train-rmse:121.621849
# [501]	train-rmse:121.599991
# [601]	train-rmse:121.597969
# Stopping. Best iteration:
# [666]	train-rmse:121.597778
# Warning message in log(y_hat + 1):
# "NaNs produced"
# Warning message in log(y_hat + 1):
# "NaNs produced"
# Progress:   0%  [1]	train-rmse:2664.469727
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:44.390900
# [201]	train-rmse:5.722174
# [301]	train-rmse:1.099635
# [401]	train-rmse:0.231712
# [501]	train-rmse:0.048687
# [601]	train-rmse:0.010476
# Stopping. Best iteration:
# [683]	train-rmse:0.002979
#
# Progress:   0%  [1]	train-rmse:2656.319580
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:19.857552
# [201]	train-rmse:1.706076
# [301]	train-rmse:0.165442
# [401]	train-rmse:0.018818
# [501]	train-rmse:0.002095
# Stopping. Best iteration:
# [504]	train-rmse:0.002015
#
# Progress:   0%  [1]	train-rmse:2660.793213
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:26.188683
# [201]	train-rmse:2.293532
# [301]	train-rmse:0.216693
# [401]	train-rmse:0.027334
# [501]	train-rmse:0.003515
# Stopping. Best iteration:
# [529]	train-rmse:0.001757
#
# Progress:   0%  [1]	train-rmse:2655.667236
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:18.764465
# [201]	train-rmse:1.632464
# [301]	train-rmse:0.149954
# [401]	train-rmse:0.017247
# [501]	train-rmse:0.001830
# Stopping. Best iteration:
# [500]	train-rmse:0.001830
#
# Progress:   0%  [1]	train-rmse:2661.622559
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:26.395800
# [201]	train-rmse:2.380850
# [301]	train-rmse:0.214078
# [401]	train-rmse:0.024443
# [501]	train-rmse:0.003123
# Stopping. Best iteration:
# [516]	train-rmse:0.002458
#
# Progress:   0%  [1]	train-rmse:2748.830322
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:57.530136
# [201]	train-rmse:4.545936
# [301]	train-rmse:0.407001
# [401]	train-rmse:0.042270
# [501]	train-rmse:0.004016
# Stopping. Best iteration:
# [530]	train-rmse:0.001980
#
# Progress:   0%  [1]	train-rmse:2656.996338
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:40.100540
# [201]	train-rmse:6.199400
# [301]	train-rmse:1.088413
# [401]	train-rmse:0.197075
# [501]	train-rmse:0.041104
# [601]	train-rmse:0.008952
# [701]	train-rmse:0.002653
# Stopping. Best iteration:
# [732]	train-rmse:0.002538
#
# Progress:   0%  [1]	train-rmse:2655.129395
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:23.091644
# [201]	train-rmse:1.716025
# [301]	train-rmse:0.175845
# [401]	train-rmse:0.018219
# [501]	train-rmse:0.002239
# Stopping. Best iteration:
# [493]	train-rmse:0.002239
#
# Progress:   0%  [1]	train-rmse:2655.974121
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:17.263500
# [201]	train-rmse:1.549178
# ...
# Stopping. Best iteration:
# [325]	train-rmse:0.001171
#
# Progress:   1%  [1]	train-rmse:2653.144775
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:5.691869
# [201]	train-rmse:0.152448
# [301]	train-rmse:0.006252
# Stopping. Best iteration:
# [352]	train-rmse:0.001029
#
# Progress:   1%  [1]	train-rmse:2649.347168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.203378
# [201]	train-rmse:0.045813
# [301]	train-rmse:0.001121
# Stopping. Best iteration:
# [297]	train-rmse:0.001121
#
# Progress:   1%  [1]	train-rmse:2651.225342
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.974761
# [201]	train-rmse:0.086412
# [301]	train-rmse:0.001653
# Stopping. Best iteration:
# [310]	train-rmse:0.001296
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.404330
# [201]	train-rmse:0.063367
# [301]	train-rmse:0.001132
# Stopping. Best iteration:
# [299]	train-rmse:0.001132
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.497620
# [201]	train-rmse:0.046178
# [301]	train-rmse:0.001324
# Stopping. Best iteration:
# [291]	train-rmse:0.001324
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.004312
# [201]	train-rmse:0.046089
# [301]	train-rmse:0.001432
# Stopping. Best iteration:
# [292]	train-rmse:0.001432
#
# Progress:   1%  [1]	train-rmse:2654.695557
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:5.517646
# [201]	train-rmse:0.178251
# [301]	train-rmse:0.007117
# Stopping. Best iteration:
# [354]	train-rmse:0.001391
#
# Progress:   1%  [1]	train-rmse:2654.539307
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:6.582373
# [201]	train-rmse:0.272152
# [301]	train-rmse:0.012385
# Stopping. Best iteration:
# [363]	train-rmse:0.001465
#
# Progress:   1%  [1]	train-rmse:2651.510986
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.950345
# [201]	train-rmse:0.074311
# [301]	train-rmse:0.001344
# Stopping. Best iteration:
# [300]	train-rmse:0.001344
#
# Progress:   1%  [1]	train-rmse:2652.327637
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.142216
# [201]	train-rmse:0.059935
# [301]	train-rmse:0.001210
# Stopping. Best iteration:
# [299]	train-rmse:0.001210
#
# Progress:   1%  [1]	train-rmse:2651.947510
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.109956
# [201]	train-rmse:0.066427
# [301]	train-rmse:0.001313
# Stopping. Best iteration:
# [294]	train-rmse:0.001313
#
# Progress:   1%  [1]	train-rmse:2651.947510
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.628036
# [201]	train-rmse:0.040974
# Stopping. Best iteration:
# [287]	train-rmse:0.001071
#
# Progress:   1%  [1]	train-rmse:2651.947510
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.455377
# [201]	train-rmse:0.072952
# [301]	train-rmse:0.001967
# Stopping. Best iteration:
# [308]	train-rmse:0.001392
#
# Progress:   1%  [1]	train-rmse:2651.947510
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.601683
# [201]	train-rmse:0.059814
# [301]	train-rmse:0.001114
# Stopping. Best iteration:
# [296]	train-rmse:0.001114
#
# Progress:   1%  [1]	train-rmse:2644.293457
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:8.107127
# [201]	train-rmse:0.327762
# [301]	train-rmse:0.020207
# Stopping. Best iteration:
# [389]	train-rmse:0.001913
#
# Progress:   1%  [1]	train-rmse:2642.651611
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.496892
# [201]	train-rmse:0.099681
# [301]	train-rmse:0.003513
# Stopping. Best iteration:
# [322]	train-rmse:0.001323
#
# Progress:   1%  [1]	train-rmse:2643.618652
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.753600
# [201]	train-rmse:0.083744
# [301]	train-rmse:0.002404
# Stopping. Best iteration:
# [311]	train-rmse:0.001635
#
# Progress:   1%  [1]	train-rmse:2642.243164
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.985638
# [201]	train-rmse:0.107565
# [301]	train-rmse:0.002901
# Stopping. Best iteration:
# [312]	train-rmse:0.002192
#
# Progress:   1%  [1]	train-rmse:2643.376953
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.975997
# [201]	train-rmse:0.094564
# [301]	train-rmse:0.003212
# Stopping. Best iteration:
# [315]	train-rmse:0.001674
#
# Progress:   1%  [1]	train-rmse:2658.133545
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:6.496511
# [201]	train-rmse:0.138243
# [301]	train-rmse:0.003380
# Stopping. Best iteration:
# [330]	train-rmse:0.001305
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.888572
# [201]	train-rmse:0.099171
# [301]	train-rmse:0.002930
# Stopping. Best iteration:
# [320]	train-rmse:0.001497
#
# Progress:   1%  [1]	train-rmse:2648.434326
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.849654
# [201]	train-rmse:0.135228
# [301]	train-rmse:0.004160
# Stopping. Best iteration:
# [330]	train-rmse:0.001458
#
# Progress:   1%  [1]	train-rmse:2641.945312
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.182970
# [201]	train-rmse:0.020449
# Stopping. Best iteration:
# [274]	train-rmse:0.001084
#
# Progress:   1%  [1]	train-rmse:2642.242920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.315435
# [201]	train-rmse:0.027051
# Stopping. Best iteration:
# [288]	train-rmse:0.000934
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.517087
# [201]	train-rmse:0.099608
# [301]	train-rmse:0.002842
# Stopping. Best iteration:
# [323]	train-rmse:0.001254
#
# Progress:   1%  [1]	train-rmse:2643.258301
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.404142
# [201]	train-rmse:0.068030
# [301]	train-rmse:0.001903
# Stopping. Best iteration:
# [305]	train-rmse:0.001725
#
# Progress:   1%  [1]	train-rmse:2641.742188
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.946979
# [201]	train-rmse:0.032796
# Stopping. Best iteration:
# [284]	train-rmse:0.001273
#
# Progress:   1%  [1]	train-rmse:2642.242920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.823918
# [201]	train-rmse:0.046505
# [301]	train-rmse:0.001179
# Stopping. Best iteration:
# [291]	train-rmse:0.001179
#
# Progress:   1%  [1]	train-rmse:2642.189941
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.039723
# [201]	train-rmse:0.029961
# Stopping. Best iteration:
# [274]	train-rmse:0.001319
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:5.014614
# [201]	train-rmse:0.238870
# [301]	train-rmse:0.011477
# Stopping. Best iteration:
# [366]	train-rmse:0.001555
#
# Progress:   1%  [1]	train-rmse:2643.258301
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:5.672715
# [201]	train-rmse:0.189344
# [301]	train-rmse:0.008467
# Stopping. Best iteration:
# [346]	train-rmse:0.001820
#
# Progress:   1%  [1]	train-rmse:2641.742188
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.935563
# [201]	train-rmse:0.062896
# [301]	train-rmse:0.001199
# Stopping. Best iteration:
# [301]	train-rmse:0.001199
#
# Progress:   1%  [1]	train-rmse:2642.242920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.158313
# [201]	train-rmse:0.076311
# [301]	train-rmse:0.001910
# Stopping. Best iteration:
# [315]	train-rmse:0.001202
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.456795
# [201]	train-rmse:0.054926
# [301]	train-rmse:0.001258
# Stopping. Best iteration:
# [296]	train-rmse:0.001258
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.009729
# [201]	train-rmse:0.048495
# [301]	train-rmse:0.001155
# Stopping. Best iteration:
# [309]	train-rmse:0.001127
#
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.999248
# [201]	train-rmse:0.060867
# [301]	train-rmse:0.001841
# Stopping. Best iteration:
# [301]	train-rmse:0.001841
#
# Progress:   1%  [1]	train-rmse:2643.293457
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.205634
# [201]	train-rmse:0.071258
# [301]	train-rmse:0.001537
# Stopping. Best iteration:
# [314]	train-rmse:0.001099
#
# Progress:   1%  [1]	train-rmse:2641.834717
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.902511
# [201]	train-rmse:0.034054
# Stopping. Best iteration:
# [274]	train-rmse:0.001416
#
# Progress:   1%  [1]	train-rmse:2642.275635
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.240342
# [201]	train-rmse:0.012847
# Stopping. Best iteration:
# [259]	train-rmse:0.001031
#
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.347801
# [201]	train-rmse:0.015318
# Stopping. Best iteration:
# [258]	train-rmse:0.001393
#
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.839211
# [201]	train-rmse:0.033162
# Stopping. Best iteration:
# [281]	train-rmse:0.001232
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.684619
# [201]	train-rmse:0.025857
# Stopping. Best iteration:
# [277]	train-rmse:0.001183
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.489545
# [201]	train-rmse:0.084928
# [301]	train-rmse:0.002667
# Stopping. Best iteration:
# [317]	train-rmse:0.001513
#
# Progress:   1%  [1]	train-rmse:2643.258301
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.826178
# [201]	train-rmse:0.098345
# [301]	train-rmse:0.003296
# Stopping. Best iteration:
# [322]	train-rmse:0.001656
#
# Progress:   1%  [1]	train-rmse:2641.741943
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.322206
# [201]	train-rmse:0.019801
# Stopping. Best iteration:
# [273]	train-rmse:0.001218
#
# Progress:   1%  [1]	train-rmse:2642.242920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.952381
# [201]	train-rmse:0.020656
# Stopping. Best iteration:
# [278]	train-rmse:0.001044
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.844635
# [201]	train-rmse:0.024154
# Stopping. Best iteration:
# [275]	train-rmse:0.001339
#
# Progress:   1%  [1]	train-rmse:2642.189941
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.107165
# [201]	train-rmse:0.033012
# [301]	train-rmse:0.000902
# Stopping. Best iteration:
# [292]	train-rmse:0.000902
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.106296
# [201]	train-rmse:0.059136
# Stopping. Best iteration:
# [281]	train-rmse:0.001270
#
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.375614
# [201]	train-rmse:0.018875
# Stopping. Best iteration:
# [262]	train-rmse:0.001374
#
# Progress:   1%  [1]	train-rmse:2652.348145
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.990904
# [201]	train-rmse:0.097714
# [301]	train-rmse:0.002493
# Stopping. Best iteration:
# [314]	train-rmse:0.001693
#
# Progress:   1%  [1]	train-rmse:2652.921387
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:4.554115
# [201]	train-rmse:0.136242
# [301]	train-rmse:0.003237
# Stopping. Best iteration:
# [322]	train-rmse:0.001706
#
# Progress:   1%  [1]	train-rmse:2649.347168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.539230
# [201]	train-rmse:0.064743
# [301]	train-rmse:0.001303
# Stopping. Best iteration:
# [299]	train-rmse:0.001303
#
# Progress:   1%  [1]	train-rmse:2651.225342
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.356569
# [201]	train-rmse:0.055824
# [301]	train-rmse:0.001281
# Stopping. Best iteration:
# [292]	train-rmse:0.001281
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.275429
# [201]	train-rmse:0.069037
# [301]	train-rmse:0.001249
# Stopping. Best iteration:
# [302]	train-rmse:0.001214
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.430357
# [201]	train-rmse:0.049240
# Stopping. Best iteration:
# [288]	train-rmse:0.001358
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.858825
# [201]	train-rmse:0.082315
# [301]	train-rmse:0.001896
# Stopping. Best iteration:
# [306]	train-rmse:0.001597
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.307795
# [201]	train-rmse:0.036740
# [301]	train-rmse:0.001027
# Stopping. Best iteration:
# [295]	train-rmse:0.001027
#
# Progress:   1%  [1]	train-rmse:2651.947510
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.938646
# [201]	train-rmse:0.033652
# Stopping. Best iteration:
# [282]	train-rmse:0.001711
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:3.010546
# [201]	train-rmse:0.068351
# [301]	train-rmse:0.002256
# Stopping. Best iteration:
# [314]	train-rmse:0.001425
#
# Progress:   1%  [1]	train-rmse:2643.258301
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.802004
# [201]	train-rmse:0.065867
# [301]	train-rmse:0.001997
# Stopping. Best iteration:
# [305]	train-rmse:0.001726
#
# Progress:   1%  [1]	train-rmse:2641.742188
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.442855
# [201]	train-rmse:0.013247
# Stopping. Best iteration:
# [257]	train-rmse:0.001138
#
# Progress:   1%  [1]	train-rmse:2642.242920
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.563833
# [201]	train-rmse:0.017730
# Stopping. Best iteration:
# [268]	train-rmse:0.001070
#
# Progress:   1%  [1]	train-rmse:2642.189941
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.805998
# [201]	train-rmse:0.020467
# Stopping. Best iteration:
# [266]	train-rmse:0.001108
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.083323
# [201]	train-rmse:0.030231
# Stopping. Best iteration:
# [281]	train-rmse:0.001046
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.349158
# [201]	train-rmse:0.048937
# [301]	train-rmse:0.001471
# Stopping. Best iteration:
# [306]	train-rmse:0.001250
#
# Progress:   1%  [1]	train-rmse:2642.222168
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.233394
# [201]	train-rmse:0.015402
# Stopping. Best iteration:
# [258]	train-rmse:0.001437
#
# Progress:   1%  [1]	train-rmse:2642.189941
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.592439
# [201]	train-rmse:0.020497
# Stopping. Best iteration:
# [264]	train-rmse:0.001425
#
# Progress:   1%  [1]	train-rmse:2650.375000
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:2.549217
# [201]	train-rmse:0.042297
# [301]	train-rmse:0.001170
# Stopping. Best iteration:
# [291]	train-rmse:0.001170
#
# Progress:   1%  [1]	train-rmse:2642.189697
# Will train until train_rmse hasn't improved in 10 rounds.
#
# [101]	train-rmse:1.566782
# [201]	train-rmse:0.014743
# Stopping. Best iteration:
# [257]	train-rmse:0.001037

# %%
mod7
# Out:
# ##### xgb.Booster
# raw: 495 Kb
# call:
#   xgb.train(params = params, data = dtrain, nrounds = nrounds,
#     watchlist = watchlist, verbose = verbose, print_every_n = print_every_n,
#     early_stopping_rounds = early_stopping_rounds, maximize = maximize,
#     save_period = save_period, save_name = save_name, xgb_model = xgb_model,
#     callbacks = callbacks)
# params (as set within xgb.train):
#   validate_parameters = "TRUE"
# xgb.attributes:
#   niter
# callbacks:
#   cb.print.evaluation(period = print_every_n)
#   cb.evaluation.log()
# # of features: 30
# niter: 250
# nfeatures : 30
# evaluation_log:
#     iter  train_rmse
#        1 2636.651855
#        2 1892.728760
# ---
#      249    0.001062
#      250    0.001062

# %%
err_res
# Out:
#   Name    Model RMSE    RMSLE
# 1 XGBoost mod7  595.799 0.2943231

# %%
err_res_df <- bind_rows(err_res, .id = "id")
err_res_df[order(err_res_df$RMSLE),]
# Out:
#      id  counter RMSE     RMSLE
# 761  1    761    585.3501 0.2834350
# 741  1    741    590.9660 0.2839988
# 1002 1   1002    586.7780 0.2858457
# 1003 1   1003    587.8954 0.2864257
# 760  1    760    591.5387 0.2866821
# 756  1    756    592.1935 0.2871575
# 922  1    922    596.5374 0.2873793
# 763  1    763    592.5473 0.2875117
# 731  1    731    617.5800 0.2889874
# 931  1    931    593.8766 0.2889940
# 1010 1   1010    594.2175 0.2896021
# 1001 1   1001    596.2210 0.2896182
# 928  1    928    599.3845 0.2897218
# 924  1    924    601.2713 0.2897467
# 746  1    746    614.6496 0.2897478
# 755  1    755    596.8322 0.2901130
# 1021 1   1021    598.5281 0.2904719
# 738  1    738    616.3895 0.2906927
# 919  1    919    616.0023 0.2907192
# 917  1    917    605.0613 0.2917515
# 758  1    758    619.5867 0.2918196
# 916  1    916    601.3304 0.2920126
# 930  1    930    599.4269 0.2920581
# 921  1    921    599.6369 0.2923704
# 740  1    740    605.2591 0.2927531
# 923  1    923    606.5739 0.2931910
# 959  1    959    600.7700 0.2932012
# 1019 1   1019    598.6782 0.2932080
# 753  1    753    619.7345 0.2933672
# 737  1    737    612.2001 0.2933831
# ...  ... ...     ...      ...
# 353  1   353     1333.867 0.5395241
# 333  1   333     1334.259 0.5405914
# 33   1    33     1337.683 0.5409526
# 125  1   125     1348.659 0.5425193
# 130  1   130     1343.007 0.5425956
# 30   1    30     1353.387 0.5427820
# 34   1    34     1340.751 0.5432008
# 39   1    39     1384.976 0.5432569
# 124  1   124     1350.130 0.5434152
# 320  1   320     1351.152 0.5441052
# 584  1   584     1346.147 0.5458342
# 144  1   144     1359.694 0.5459398
# 36   1    36     1375.242 0.5470546
# 129  1   129     1356.800 0.5477365
# 44   1    44     1363.570 0.5483093
# 41   1    41     1361.090 0.5489316
# 319  1   319     1364.056 0.5503200
# 121  1   121     1371.789 0.5517336
# 126  1   126     1375.096 0.5551173
# 141  1   141     1378.181 0.5553895
# 316  1   316     1379.844 0.5576796
# 29   1    29     1412.146 0.5676225
# 3    1     3     1412.313 0.5682603
# 120  1   120     1415.623 0.5687437
# 5    1     5     1414.919 0.5689187
# 35   1    35     1417.412 0.5689431
# 28   1    28     1418.453 0.5696475
# 4    1     4     1424.141 0.5714773
# 10   1    10     1479.094 0.5732605
# 9    1     9     1588.989 0.5895690

# %%
best_comb <- variables_comb[761]

# %%
# specifications of how to model,
# coming from somewhere else
outcome <- "cnt"
variables <- c("season","mnth","holiday","weekday","workingday","weathersit","temp","atemp","hum","windspeed")
best_comb <- unlist(best_comb)

f <- as.formula(
  paste(outcome, 
        paste(best_comb, collapse = " + "), 
        sep = " ~ "))
print(f)
# Out:
# cnt ~ season + workingday + weathersit + atemp + hum + windspeed

# %%
mod3 <- randomForest(f, data=train)
mod3
# Out:
# Call:
#  randomForest(formula = f, data = train)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 2
#
#           Mean of squared residuals: 289712.9
#                     % Var explained: 84.36

# %%
pred3 <- predict(mod3,newdata=test)

rmse(test$cnt,pred3)
rmsle(test$cnt,pred3)
# Out:
# [1] 590.8196
# [1] 0.2837038

# %%
real_test <- read.csv("test.csv")
head(real_test)
dim(real_test)
# Out:
#   id  season mnth holiday weekday workingday weathersit temp     atemp
# 1 366 1      1    0       0       0          1          0.370000 0.375621
# 2 367 1      1    1       1       0          1          0.273043 0.252304
# 3 368 1      1    0       2       1          1          0.150000 0.126275
# 4 369 1      1    0       3       1          2          0.107500 0.119337
# 5 370 1      1    0       4       1          1          0.265833 0.278412
# 6 371 1      1    0       5       1          1          0.334167 0.340267
#   hum      windspeed
# 1 0.692500 0.192167
# 2 0.381304 0.329665
# 3 0.441250 0.365671
# 4 0.414583 0.184700
# 5 0.524167 0.129987
# 6 0.542083 0.167908
# [1] 366  11

# %%
real_test$holiday <- as.factor(real_test$holiday)
real_test$season <- as.factor(real_test$season)
real_test$mnth <- as.factor(real_test$mnth)
real_test$workingday <- as.factor(real_test$workingday)
real_test$weathersit <- as.factor(real_test$weathersit)
real_test$weekday <- as.factor(real_test$weekday)

# %%
real_test$cnt <- predict(mod3,newdata=real_test)
real_test_sub <- real_test %>% select(id, cnt)

# %%
plot(real_test_sub)
# Out:
# plot without title

# %%
write.csv(real_test_sub,"C:\\Users\\ytsat\\Documents\\DataScience\\ML\\Kaggle_Challenge\\RandomForest_v1.csv", row.names = FALSE)
