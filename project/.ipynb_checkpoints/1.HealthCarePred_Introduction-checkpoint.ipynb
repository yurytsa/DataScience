# %% [markdown]
# # ABOUT

# %% [markdown]
# #### The rising cost of healthcare is one of the world’s most important problems. Healthcare policy researchers have devoted much effort toward finding solutions to the fast growth in health care spending over the past decade.Health insurance expenditures are not evenly distributed among the insured population. As you can see in the graphs below, spending on the top decile is about returning to spending on the rest of the population. In this light, it is very important for health funds to be able to predict the level of expenditure on a specific insured. This prediction should be based on characteristics that exist for each insured, such as the existence of chronic diseases and diagnoses of health status.

# %%
from IPython.display import Image
Image("http://xiner-shirley-paula.github.io/DataScienceFinalProject/img/highcost.png")
