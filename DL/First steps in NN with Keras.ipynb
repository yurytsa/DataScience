# %% [markdown]
# # First stetps in Neural Network with Keras

# %%
import numpy as np
import pandas as pd

# fix random seed for reproducibility
np.random.seed(3)

# %%
dataset = pd.read_csv("C:/Users/Thomas/Documents/BIDS/ML/mtcars.csv")
dataset.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %% [markdown]
# For this example we will use the mtcars dataset.

# %%
# split into input (X) and output (Y) variables
nv = ["mpg","cyl","disp","hp","drat","wt","qsec","vs","gear","carb"]
X = np.array(dataset[nv])
y = np.array(dataset["am"])

# %%
X.shape
# Out:
# (32, 10)

# %% [markdown]
# ## Defining the Neural Network Architecture
#
# First we have to import in keras the "Sequential" function. This is the most common NN type, that means we are going to define our NN one layer a time. The other possible architecture available is the "Functional" function, which permits a more flexible architecture by letting join many structures in parallel.
#
# Then we initialize the NN by defining our model object and will add to it the layers as we defined in our network architecture plan.
#
# The layers that we will use are fully conected layers, which means that we want that all the input data from the previous layer will be connedted with all the nodes of this layer. In keras we call this layer type "Dense".
#
# When defining the layer we have to provide some parameters: input_dim is the dimmention of the input (in our case we have 10 inputs (variables) that enter our hidden layer.
#
# Another parameter is the activation function. We can define this function inside the layer definition, or separately (see alternatives 1 and 2).

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# In Keras, there are two main ways to define the topology of a neural network:
#
# 1) by adding each layer to the main object:

# %%
# We will now create the NN architecture
model = Sequential()
model.add(Dense(12, input_dim=10))
model.add(Activation('relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# 2) by adding the layers while defining the main object

# %%
model = Sequential([
    Dense(12, input_dim=10, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# ## Training the model
#
# To run our NN we have first to "compile" our model. The compilation require us to define some important parameters:
#
# 1. Define the <b>loss function</b>: this is the measure of the error. There are many types of loss functions that could be applied in NN's:
#  - mean_squared_error
#  - mean_absolute_error
#  - mean_absolute_percentage_error
#  - mean_squared_logarithmic_error
#  - squared_hinge
#  - hinge
#  - categorical_hinge
#  - logcosh
#  - categorical_crossentropy
#  - sparse_categorical_crossentropy
#  - binary_crossentropy
#  - kullback_leibler_divergence
#  - poisson
#  - cosine_proximity
#
#
# 2. Define the <b>optimizer</b>: this is the method we want to apply for the gradient descent. Some popular methods are:
#  - Stochastic gradient descent (SGD)
#  - Adaptive moment estimator (Adam)
#  - batch gradient descent
#  - mini-batch gradient descent
#  - Nesterov accelerated gradient (NAG)
#  - Adagrad
#  - AdaDelta
#  - RMSprop
#
#
# 3. Define the <b>metrics</b>: Metric values are recorded at the end of each epoch on the training dataset. The most common metrics are:
#  + For regression output:
#     - Mean Squared Error (MSE)
#     - Mean Absolute Error (MAE)
#     - Mean Absolute Percentage Error (MAPE)
#     - Cosine Proximity
#
#  + For classification output:
#     - Binary Accuracy
#     - Categorical Accuracy
#     - Sparse Categorical Accuracy
#     - Top k Categorical Accuracy
#     - Sparse Top k Categorical Accuracy

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 12)                132
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# After compilation, the model could be trained. We use the fit function to begin the training.

# %%
# Fit the model
res = model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5937 - accuracy: 0.4062
# Epoch 2/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5937 - accuracy: 0.4062
# Epoch 3/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5931 - accuracy: 0.4062
# Epoch 4/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.4062
# Epoch 5/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.4062
# Epoch 6/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5655 - accuracy: 0.4375
# Epoch 7/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5668 - accuracy: 0.4375
# Epoch 8/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5708 - accuracy: 0.4062
# Epoch 9/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5695 - accuracy: 0.4375
# Epoch 10/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5651 - accuracy: 0.4375
# Epoch 11/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5642 - accuracy: 0.4375
# Epoch 12/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5645 - accuracy: 0.4375
# Epoch 13/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5645 - accuracy: 0.4375
# Epoch 14/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5640 - accuracy: 0.4375
# Epoch 15/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5637 - accuracy: 0.4375
# Epoch 16/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5637 - accuracy: 0.4375
# Epoch 17/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5639 - accuracy: 0.4375
# Epoch 18/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5632 - accuracy: 0.4375
# Epoch 19/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5630 - accuracy: 0.4375
# Epoch 20/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.4375
# Epoch 21/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.5621 - accuracy: 0.4375
# Epoch 22/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5613 - accuracy: 0.4375
# Epoch 23/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5401 - accuracy: 0.4375
# Epoch 24/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5107 - accuracy: 0.4688
# Epoch 25/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.4249 - accuracy: 0.5312
# Epoch 26/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3050 - accuracy: 0.6562
# Epoch 27/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.5938
# Epoch 28/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.3094 - accuracy: 0.6562
# Epoch 29/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2923 - accuracy: 0.6875
# Epoch 30/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3020 - accuracy: 0.6875
# Epoch 31/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3001 - accuracy: 0.6875
# Epoch 32/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2989 - accuracy: 0.6875
# Epoch 33/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.6875
# Epoch 34/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2898 - accuracy: 0.6875
# Epoch 35/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2871 - accuracy: 0.7188
# Epoch 36/150
# 4/4 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.90 - 0s 999us/step - loss: 0.2860 - accuracy: 0.7188
# Epoch 37/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2848 - accuracy: 0.7188
# Epoch 38/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2836 - accuracy: 0.7188
# Epoch 39/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.7188
# Epoch 40/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2828 - accuracy: 0.7188
# Epoch 41/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2827 - accuracy: 0.7188
# Epoch 42/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2824 - accuracy: 0.7188
# Epoch 43/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2822 - accuracy: 0.7188
# Epoch 44/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2821 - accuracy: 0.7188
# Epoch 45/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2820 - accuracy: 0.7188
# Epoch 46/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.7188
# Epoch 47/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2819 - accuracy: 0.7188
# Epoch 48/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2818 - accuracy: 0.7188
# Epoch 49/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2818 - accuracy: 0.7188
# Epoch 50/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 51/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 52/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 53/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 54/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 55/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.7188
# Epoch 56/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2816 - accuracy: 0.7188
# Epoch 57/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2816 - accuracy: 0.7188
# Epoch 58/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2816 - accuracy: 0.7188
# Epoch 59/150
# 4/4 [==============================] - 0s 745us/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 60/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 61/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 62/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 63/150
# 4/4 [==============================] - 0s 995us/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 64/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 65/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 66/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 67/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 68/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 69/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 0.7188
# Epoch 70/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 71/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 72/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 73/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 74/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 75/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 76/150
# 4/4 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.70 - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 77/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 78/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 79/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 80/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 81/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 82/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 83/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 84/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 85/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 86/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 87/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 88/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 89/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.7188
# Epoch 90/150
# 4/4 [==============================] - 0s 751us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 91/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 92/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 93/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 94/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 95/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 96/150
# 4/4 [==============================] - 0s 996us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 97/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 98/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 99/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 100/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 101/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 102/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 103/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 104/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 105/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 106/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 107/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 108/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 109/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 110/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 111/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 112/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 113/150
# 4/4 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.70 - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 114/150
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 115/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 116/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 117/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 118/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 119/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 120/150
# 4/4 [==============================] - 0s 747us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 121/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 122/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 123/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 124/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 125/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 126/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 127/150
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 128/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 129/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 130/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 131/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 132/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 133/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 134/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 135/150
# 4/4 [==============================] - 0s 751us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 136/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 137/150
# 4/4 [==============================] - 0s 749us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 138/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 139/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 140/150
# 4/4 [==============================] - 0s 750us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 141/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 142/150
# 4/4 [==============================] - 0s 741us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 143/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 144/150
# 4/4 [==============================] - 0s 746us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 145/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 146/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 147/150
# 4/4 [==============================] - 0s 751us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 148/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 149/150
# 4/4 [==============================] - 0s 745us/step - loss: 0.2813 - accuracy: 0.7188
# Epoch 150/150
# 4/4 [==============================] - 0s 999us/step - loss: 0.2813 - accuracy: 0.7188

# %%
res.history['loss']
# Out:
# [0.5937349796295166,
#  0.5937007665634155,
#  0.5931087136268616,
#  0.5912346243858337,
#  0.574558436870575,
#  0.5655300617218018,
#  0.5668033361434937,
#  0.5708123445510864,
#  0.5695240497589111,
#  0.5650796294212341,
#  0.5642009973526001,
#  0.5644505023956299,
#  0.5645431280136108,
#  0.5640136003494263,
#  0.5637256503105164,
#  0.5636915564537048,
#  0.5639429092407227,
#  0.5632441639900208,
#  0.5630249977111816,
#  0.5626682043075562,
#  0.5620876550674438,
#  0.5613155961036682,
#  0.5400829315185547,
#  0.5106815099716187,
#  0.42494866251945496,
#  0.30495578050613403,
#  0.3225219249725342,
#  0.3094434440135956,
#  0.2922962009906769,
#  0.3020491302013397,
#  0.30008071660995483,
#  0.29887160658836365,
#  0.29390567541122437,
#  0.28983864188194275,
#  0.28714796900749207,
#  0.2860458493232727,
#  0.2848273813724518,
#  0.2835729122161865,
#  0.2829551696777344,
#  0.2828056216239929,
#  0.28267887234687805,
#  0.2824162244796753,
#  0.2822485566139221,
#  0.2820824384689331,
#  0.28202399611473083,
#  0.281938374042511,
#  0.2818944454193115,
#  0.28181910514831543,
#  0.2818121016025543,
#  0.28173694014549255,
#  0.28174877166748047,
#  0.2817472219467163,
#  0.2817414402961731,
#  0.28171291947364807,
#  0.2816832959651947,
#  0.28164350986480713,
#  0.28160491585731506,
#  0.28158098459243774,
#  0.281541645526886,
#  0.2815294563770294,
#  0.28151243925094604,
#  0.2815081477165222,
#  0.28149133920669556,
#  0.2814851403236389,
#  0.2814779281616211,
#  0.28146955370903015,
#  0.28146034479141235,
#  0.2814558744430542,
#  0.28145459294319153,
#  0.28144571185112,
#  0.28143951296806335,
#  0.281434029340744,
#  0.28142914175987244,
#  0.2814219295978546,
#  0.2814120650291443,
#  0.2814091742038727,
#  0.2814050018787384,
#  0.2814025282859802,
#  0.2814047634601593,
#  0.2814016342163086,
#  0.2813847064971924,
#  0.2813746929168701,
#  0.2813687026500702,
#  0.28136539459228516,
#  0.281361848115921,
#  0.2813589870929718,
#  0.2813568115234375,
#  0.2813543975353241,
#  0.28135091066360474,
#  0.28134894371032715,
#  0.28134506940841675,
#  0.28134238719940186,
#  0.2813407778739929,
#  0.2813384532928467,
#  0.281335711479187,
#  0.28133493661880493,
#  0.2813325524330139,
#  0.2813304662704468,
#  0.28132835030555725,
#  0.28132495284080505,
#  0.2813217043876648,
#  0.2813204824924469,
#  0.2813188433647156,
#  0.28131812810897827,
#  0.28131601214408875,
#  0.2813148498535156,
#  0.28131234645843506,
#  0.28131037950515747,
#  0.28130877017974854,
#  0.2813083529472351,
#  0.2813050150871277,
#  0.2813039720058441,
#  0.28130418062210083,
#  0.2813020348548889,
#  0.2813006639480591,
#  0.28129902482032776,
#  0.2812967300415039,
#  0.2812952995300293,
#  0.2812937796115875,
#  0.281292587518692,
#  0.28129130601882935,
#  0.281289279460907,
#  0.281289666891098,
#  0.2812889516353607,
#  0.28128582239151,
#  0.2812851369380951,
#  0.28128328919410706,
#  0.2812821865081787,
#  0.2812814712524414,
#  0.2812801003456116,
#  0.28127896785736084,
#  0.281278133392334,
#  0.2812773883342743,
#  0.2812765836715698,
#  0.28127461671829224,
#  0.2812756896018982,
#  0.2812737822532654,
#  0.28127360343933105,
#  0.2812729775905609,
#  0.2812725901603699,
#  0.28127163648605347,
#  0.28127115964889526,
#  0.28127047419548035,
#  0.28126972913742065,
#  0.2812693119049072,
#  0.28126877546310425,
#  0.28126826882362366,
#  0.2812677025794983,
#  0.2812674045562744,
#  0.281266450881958]

# %% [markdown]
# We now will check the performance of the model by comparing the prediction (yhat) with the original label (y)

# %%
# evaluate the model
scores = model.evaluate(X, y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.2813 - accuracy: 0.7188
#
# accuracy: 71.88%

# %% [markdown]
# ## Predicting using the model
#
# We can then use the predict function to run the trained model on a new (test) dataset:

# %%
# calculate predictions
predictions = model.predict(X)
# round predictions
rounded = [round(x[0]) for x in predictions]
#print(rounded)

# %%
df = pd.DataFrame({'yhat':rounded,'y':y})
print(df)
# Out:
#     yhat  y
# 0    1.0  1
# 1    1.0  1
# 2    1.0  1
# 3    0.0  0
# 4    0.0  0
# 5    0.0  0
# 6    1.0  0
# 7    0.0  0
# 8    1.0  0
# 9    1.0  0
# 10   1.0  0
# 11   1.0  0
# 12   1.0  0
# 13   1.0  0
# 14   0.0  0
# 15   0.0  0
# 16   0.0  0
# 17   1.0  1
# 18   1.0  1
# 19   1.0  1
# 20   1.0  0
# 21   0.0  0
# 22   0.0  0
# 23   1.0  0
# 24   0.0  0
# 25   1.0  1
# 26   1.0  1
# 27   1.0  1
# 28   1.0  1
# 29   1.0  1
# 30   1.0  1
# 31   1.0  1

# %%
pd.crosstab(df.y,df.yhat)
# Out:
# yhat  0.0  1.0
# y
# 0      10    9
# 1       0   13

# %% [markdown]
# <iframe src="/assets/conv-demo/index.html" width="100%" height="700px;" style="border:none;"></iframe>
