# %% [markdown]
# # Python Intro - Part 3

# %% [markdown]
# # Working with Pandas Data Frames

# %%
import pandas as pd
 
iris = pd.read_csv("..\data\iris.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
## add new colums to the df
iris['sepal_ratio'] = iris.sepal_length / iris.sepal_width
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_ratio
# 0           5.1          3.5           1.4          0.2  setosa     1.457143
# 1           4.9          3.0           1.4          0.2  setosa     1.633333
# 2           4.7          3.2           1.3          0.2  setosa     1.468750
# 3           4.6          3.1           1.5          0.2  setosa     1.483871
# 4           5.0          3.6           1.4          0.2  setosa     1.388889

# %%
iris['petal_ratio'] = iris.petal_length / iris['petal_width']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_ratio  \
# 0           5.1          3.5           1.4          0.2  setosa     1.457143
# 1           4.9          3.0           1.4          0.2  setosa     1.633333
# 2           4.7          3.2           1.3          0.2  setosa     1.468750
# 3           4.6          3.1           1.5          0.2  setosa     1.483871
# 4           5.0          3.6           1.4          0.2  setosa     1.388889
#
#    petal_ratio
# 0          7.0
# 1          7.0
# 2          6.5
# 3          7.5
# 4          7.0

# %%
## now proceed with checking the values of the df
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_ratio  \
# count    150.000000   150.000000    150.000000   150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667     1.955144
# std        0.828066     0.433594      1.764420     0.763161     0.398697
# min        4.300000     2.000000      1.000000     0.100000     1.268293
# 25%        5.100000     2.800000      1.600000     0.300000     1.551915
# 50%        5.800000     3.000000      4.350000     1.300000     2.032292
# 75%        6.400000     3.300000      5.100000     1.800000     2.224910
# max        7.900000     4.400000      6.900000     2.500000     2.961538
#
#        petal_ratio
# count   150.000000
# mean      4.367166
# std       2.651508
# min       2.125000
# 25%       2.802381
# 50%       3.300000
# 75%       4.666667
# max      15.000000

# %%
## create categorical variables for the sepal and petal width
iris['petalw_cat'] = pd.np.floor(iris.petal_width)
iris['sepalw_cat'] = pd.np.floor(iris.sepal_width)
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_ratio  \
# count    150.000000   150.000000    150.000000   150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667     1.955144
# std        0.828066     0.433594      1.764420     0.763161     0.398697
# min        4.300000     2.000000      1.000000     0.100000     1.268293
# 25%        5.100000     2.800000      1.600000     0.300000     1.551915
# 50%        5.800000     3.000000      4.350000     1.300000     2.032292
# 75%        6.400000     3.300000      5.100000     1.800000     2.224910
# max        7.900000     4.400000      6.900000     2.500000     2.961538
#
#        petal_ratio  petalw_cat  sepalw_cat
# count   150.000000  150.000000  150.000000
# mean      4.367166    0.860000    2.646667
# std       2.651508    0.714472    0.532648
# min       2.125000    0.000000    2.000000
# 25%       2.802381    0.000000    2.000000
# 50%       3.300000    1.000000    3.000000
# 75%       4.666667    1.000000    3.000000
# max      15.000000    2.000000    4.000000

# %%
## subsetting
iris[iris.petalw_cat==2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 100           6.3          3.3           6.0          2.5  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
#      sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# 100     1.909091     2.400000         2.0         3.0
# 102     2.366667     2.809524         2.0         3.0
# 104     2.166667     2.636364         2.0         3.0
# 105     2.533333     3.142857         2.0         3.0
# 109     2.000000     2.440000         2.0         3.0
# 110     2.031250     2.550000         2.0         3.0
# 112     2.266667     2.619048         2.0         3.0
# 113     2.280000     2.500000         2.0         2.0
# 114     2.071429     2.125000         2.0         2.0
# 115     2.000000     2.304348         2.0         3.0
# 117     2.026316     3.045455         2.0         3.0
# 118     2.961538     3.000000         2.0         2.0
# 120     2.156250     2.478261         2.0         3.0
# 121     2.000000     2.450000         2.0         2.0
# 122     2.750000     3.350000         2.0         2.0
# 124     2.030303     2.714286         2.0         3.0
# 128     2.285714     2.666667         2.0         2.0
# 131     2.078947     3.200000         2.0         3.0
# 132     2.285714     2.545455         2.0         2.0
# 135     2.566667     2.652174         2.0         3.0
# 136     1.852941     2.333333         2.0         3.0
# 139     2.225806     2.571429         2.0         3.0
# 140     2.161290     2.333333         2.0         3.0
# 141     2.225806     2.217391         2.0         3.0
# 143     2.125000     2.565217         2.0         3.0
# 144     2.030303     2.280000         2.0         3.0
# 145     2.233333     2.260870         2.0         3.0
# 147     2.166667     2.600000         2.0         3.0
# 148     1.823529     2.347826         2.0         3.0

# %%
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count   150.000000   150.000000  150.000000  150.000000
# mean      1.953681     4.310500    0.860000    2.646667
# std       0.400480     2.489648    0.714472    0.532648
# min       1.268293     2.125000    0.000000    2.000000
# 25%       1.546188     2.802381    0.000000    2.000000
# 50%       2.032292     3.300000    1.000000    3.000000
# 75%       2.224910     4.666667    1.000000    3.000000
# max       2.961538    15.000000    2.000000    4.000000

# %%
### subsetting for given values
iris[iris.species.isin(['virginica','versicolor'])]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# 57            4.9          2.4           3.3          1.0  versicolor
# 58            6.6          2.9           4.6          1.3  versicolor
# 59            5.2          2.7           3.9          1.4  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 61            5.9          3.0           4.2          1.5  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 64            5.6          2.9           3.6          1.3  versicolor
# 65            6.7          3.1           4.4          1.4  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 67            5.8          2.7           4.1          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 69            5.6          2.5           3.9          1.1  versicolor
# 70            5.9          3.2           4.8          1.8  versicolor
# 71            6.1          2.8           4.0          1.3  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
# 74            6.4          2.9           4.3          1.3  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 76            6.8          2.8           4.8          1.4  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# ..            ...          ...           ...          ...         ...
# 120           6.9          3.2           5.7          2.3   virginica
# 121           5.6          2.8           4.9          2.0   virginica
# 122           7.7          2.8           6.7          2.0   virginica
# 123           6.3          2.7           4.9          1.8   virginica
# 124           6.7          3.3           5.7          2.1   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 126           6.2          2.8           4.8          1.8   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 128           6.4          2.8           5.6          2.1   virginica
# 129           7.2          3.0           5.8          1.6   virginica
# 130           7.4          2.8           6.1          1.9   virginica
# 131           7.9          3.8           6.4          2.0   virginica
# 132           6.4          2.8           5.6          2.2   virginica
# 133           6.3          2.8           5.1          1.5   virginica
# 134           6.1          2.6           5.6          1.4   virginica
# 135           7.7          3.0           6.1          2.3   virginica
# 136           6.3          3.4           5.6          2.4   virginica
# 137           6.4          3.1           5.5          1.8   virginica
# 138           6.0          3.0           4.8          1.8   virginica
# 139           6.9          3.1           5.4          2.1   virginica
# 140           6.7          3.1           5.6          2.4   virginica
# 141           6.9          3.1           5.1          2.3   virginica
# 142           5.8          2.7           5.1          1.9   virginica
# 143           6.8          3.2           5.9          2.3   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
#      sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# 50      2.187500     3.357143         1.0         3.0
# 51      2.000000     3.000000         1.0         3.0
# 52      2.225806     3.266667         1.0         3.0
# 53      2.391304     3.076923         1.0         2.0
# 54      2.321429     3.066667         1.0         2.0
# 55      2.035714     3.461538         1.0         2.0
# 56      1.909091     2.937500         1.0         3.0
# 57      2.041667     3.300000         1.0         2.0
# 58      2.275862     3.538462         1.0         2.0
# 59      1.925926     2.785714         1.0         2.0
# 60      2.500000     3.500000         1.0         2.0
# 61      1.966667     2.800000         1.0         3.0
# 62      2.727273     4.000000         1.0         2.0
# 63      2.103448     3.357143         1.0         2.0
# 64      1.931034     2.769231         1.0         2.0
# 65      2.161290     3.142857         1.0         3.0
# 66      1.866667     3.000000         1.0         3.0
# 67      2.148148     4.100000         1.0         2.0
# 68      2.818182     3.000000         1.0         2.0
# 69      2.240000     3.545455         1.0         2.0
# 70      1.843750     2.666667         1.0         3.0
# 71      2.178571     3.076923         1.0         2.0
# 72      2.520000     3.266667         1.0         2.0
# 73      2.178571     3.916667         1.0         2.0
# 74      2.206897     3.307692         1.0         2.0
# 75      2.200000     3.142857         1.0         3.0
# 76      2.428571     3.428571         1.0         2.0
# 77      2.233333     2.941176         1.0         3.0
# 78      2.068966     3.000000         1.0         2.0
# 79      2.192308     3.500000         1.0         2.0
# ..           ...          ...         ...         ...
# 120     2.156250     2.478261         2.0         3.0
# 121     2.000000     2.450000         2.0         2.0
# 122     2.750000     3.350000         2.0         2.0
# 123     2.333333     2.722222         1.0         2.0
# 124     2.030303     2.714286         2.0         3.0
# 125     2.250000     3.333333         1.0         3.0
# 126     2.214286     2.666667         1.0         2.0
# 127     2.033333     2.722222         1.0         3.0
# 128     2.285714     2.666667         2.0         2.0
# 129     2.400000     3.625000         1.0         3.0
# 130     2.642857     3.210526         1.0         2.0
# 131     2.078947     3.200000         2.0         3.0
# 132     2.285714     2.545455         2.0         2.0
# 133     2.250000     3.400000         1.0         2.0
# 134     2.346154     4.000000         1.0         2.0
# 135     2.566667     2.652174         2.0         3.0
# 136     1.852941     2.333333         2.0         3.0
# 137     2.064516     3.055556         1.0         3.0
# 138     2.000000     2.666667         1.0         3.0
# 139     2.225806     2.571429         2.0         3.0
# 140     2.161290     2.333333         2.0         3.0
# 141     2.225806     2.217391         2.0         3.0
# 142     2.148148     2.684211         1.0         2.0
# 143     2.125000     2.565217         2.0         3.0
# 144     2.030303     2.280000         2.0         3.0
# 145     2.233333     2.260870         2.0         3.0
# 146     2.520000     2.631579         1.0         2.0
# 147     2.166667     2.600000         2.0         3.0
# 148     1.823529     2.347826         2.0         3.0
# 149     1.966667     2.833333         1.0         3.0
#
# [100 rows x 9 columns]

# %%
# subsetting between values

iris2 = iris.copy()
iris2 = iris2[iris2['petal_length'].between(5,6)]
iris2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_ratio  \
# count     37.000000    37.000000     37.000000    37.000000    37.000000
# mean       6.454054     2.954054      5.432432     2.016216     2.198928
# std        0.395527     0.280470      0.318899     0.297689     0.193236
# min        5.700000     2.200000      5.000000     1.400000     1.823529
# 25%        6.300000     2.800000      5.100000     1.800000     2.071429
# 50%        6.400000     3.000000      5.500000     2.000000     2.172414
# 75%        6.700000     3.200000      5.700000     2.300000     2.280000
# max        7.200000     3.400000      6.000000     2.500000     2.727273
#
#        petal_ratio  petalw_cat  sepalw_cat
# count    37.000000   37.000000   37.000000
# mean      2.749890    1.567568    2.621622
# std       0.426338    0.502247    0.491672
# min       2.125000    1.000000    2.000000
# 25%       2.478261    1.000000    2.000000
# 50%       2.636364    2.000000    3.000000
# 75%       3.055556    2.000000    3.000000
# max       4.000000    2.000000    3.000000

# %%
iris.describe()
# Out:
#        Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000
#
#        sepal_ratio  petal_ratio  petalw_cat  sepalw_cat
# count   150.000000   150.000000  150.000000  150.000000
# mean      1.953681     4.310500    0.860000    2.646667
# std       0.400480     2.489648    0.714472    0.532648
# min       1.268293     2.125000    0.000000    2.000000
# 25%       1.546188     2.802381    0.000000    2.000000
# 50%       2.032292     3.300000    1.000000    3.000000
# 75%       2.224910     4.666667    1.000000    3.000000
# max       2.961538    15.000000    2.000000    4.000000

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
### aggregate - added to pandas version 0.20.0 !!!
iris.agg({'petal_ratio':[min,max,"mean","median",len],'sepal_ratio':[min,max,"mean","median",len]})
# Out:
#         petal_ratio  sepal_ratio
# min          2.1250     1.268293
# max         15.0000     2.961538
# mean         4.3105     1.953681
# median       3.3000     2.032292
# len        150.0000   150.000000

# %%
iris.groupby('species').agg({'sepal_length':[min,max,len]})
# Out:
#            sepal_length
#                     min  max   len
# species
# setosa              4.3  5.8  50.0
# versicolor          4.9  7.0  50.0
# virginica           4.9  7.9  50.0

# %% [markdown]
#  iris %>% filter() %>% group_by() %>% summarise()

# %%
### getting all together (like with dplyr in R)
# 1. filter
# 2. group
# 3. summarise
iris[(iris.sepalw_cat.isin([0,2,3])) & (iris['petal_length'].between(1,4))].\
    groupby('species').\
    agg({'sepal_ratio':[min,"mean","median",max,len], 'petal_ratio':[min,"mean","median",max,len]})
# Out:
#            sepal_ratio                                     petal_ratio  \
#                    min      mean    median       max   len         min
# species
# setosa        1.277778  1.482307  1.468750  1.956522  46.0    2.666667
# versicolor    1.925926  2.219015  2.196154  2.727273  16.0    2.727273
#
#
#                 mean median   max   len
# species
# setosa      6.818478    7.0  15.0  46.0
# versicolor  3.274770    3.3   4.0  16.0

# %% [markdown]
# # Working with Files (I/O)
#
# #### Read, write and append data

# %%
f = open("..\data\iris.csv",'r')
### read the first line
f.readline()
# Out:
# 'sepal_length,sepal_width,petal_length,petal_width,species\n'

# %%
### read the next line
f.readline()
# Out:
# '5.1,3.5,1.4,0.2,setosa\n'

# %%
### read the next line
f.readline()
# Out:
# '4.9,3.0,1.4,0.2,setosa\n'

# %%
### read the next lines after the actual cursor
f.readlines()
# Out:
# ['4.7,3.2,1.3,0.2,setosa\n',
#  '4.6,3.1,1.5,0.2,setosa\n',
#  '5.0,3.6,1.4,0.2,setosa\n',
#  '5.4,3.9,1.7,0.4,setosa\n',
#  '4.6,3.4,1.4,0.3,setosa\n',
#  '5.0,3.4,1.5,0.2,setosa\n',
#  '4.4,2.9,1.4,0.2,setosa\n',
#  '4.9,3.1,1.5,0.1,setosa\n',
#  '5.4,3.7,1.5,0.2,setosa\n',
#  '4.8,3.4,1.6,0.2,setosa\n',
#  '4.8,3.0,1.4,0.1,setosa\n',
#  '4.3,3.0,1.1,0.1,setosa\n',
#  '5.8,4.0,1.2,0.2,setosa\n',
#  '5.7,4.4,1.5,0.4,setosa\n',
#  '5.4,3.9,1.3,0.4,setosa\n',
#  '5.1,3.5,1.4,0.3,setosa\n',
#  '5.7,3.8,1.7,0.3,setosa\n',
#  '5.1,3.8,1.5,0.3,setosa\n',
#  '5.4,3.4,1.7,0.2,setosa\n',
#  '5.1,3.7,1.5,0.4,setosa\n',
#  '4.6,3.6,1.0,0.2,setosa\n',
#  '5.1,3.3,1.7,0.5,setosa\n',
#  '4.8,3.4,1.9,0.2,setosa\n',
#  '5.0,3.0,1.6,0.2,setosa\n',
#  '5.0,3.4,1.6,0.4,setosa\n',
#  '5.2,3.5,1.5,0.2,setosa\n',
#  '5.2,3.4,1.4,0.2,setosa\n',
#  '4.7,3.2,1.6,0.2,setosa\n',
#  '4.8,3.1,1.6,0.2,setosa\n',
#  '5.4,3.4,1.5,0.4,setosa\n',
#  '5.2,4.1,1.5,0.1,setosa\n',
#  '5.5,4.2,1.4,0.2,setosa\n',
#  '4.9,3.1,1.5,0.1,setosa\n',
#  '5.0,3.2,1.2,0.2,setosa\n',
#  '5.5,3.5,1.3,0.2,setosa\n',
#  '4.9,3.1,1.5,0.1,setosa\n',
#  '4.4,3.0,1.3,0.2,setosa\n',
#  '5.1,3.4,1.5,0.2,setosa\n',
#  '5.0,3.5,1.3,0.3,setosa\n',
#  '4.5,2.3,1.3,0.3,setosa\n',
#  '4.4,3.2,1.3,0.2,setosa\n',
#  '5.0,3.5,1.6,0.6,setosa\n',
#  '5.1,3.8,1.9,0.4,setosa\n',
#  '4.8,3.0,1.4,0.3,setosa\n',
#  '5.1,3.8,1.6,0.2,setosa\n',
#  '4.6,3.2,1.4,0.2,setosa\n',
#  '5.3,3.7,1.5,0.2,setosa\n',
#  '5.0,3.3,1.4,0.2,setosa\n',
#  '7.0,3.2,4.7,1.4,versicolor\n',
#  '6.4,3.2,4.5,1.5,versicolor\n',
#  '6.9,3.1,4.9,1.5,versicolor\n',
#  '5.5,2.3,4.0,1.3,versicolor\n',
#  '6.5,2.8,4.6,1.5,versicolor\n',
#  '5.7,2.8,4.5,1.3,versicolor\n',
#  '6.3,3.3,4.7,1.6,versicolor\n',
#  '4.9,2.4,3.3,1.0,versicolor\n',
#  '6.6,2.9,4.6,1.3,versicolor\n',
#  '5.2,2.7,3.9,1.4,versicolor\n',
#  '5.0,2.0,3.5,1.0,versicolor\n',
#  '5.9,3.0,4.2,1.5,versicolor\n',
#  '6.0,2.2,4.0,1.0,versicolor\n',
#  '6.1,2.9,4.7,1.4,versicolor\n',
#  '5.6,2.9,3.6,1.3,versicolor\n',
#  '6.7,3.1,4.4,1.4,versicolor\n',
#  '5.6,3.0,4.5,1.5,versicolor\n',
#  '5.8,2.7,4.1,1.0,versicolor\n',
#  '6.2,2.2,4.5,1.5,versicolor\n',
#  '5.6,2.5,3.9,1.1,versicolor\n',
#  '5.9,3.2,4.8,1.8,versicolor\n',
#  '6.1,2.8,4.0,1.3,versicolor\n',
#  '6.3,2.5,4.9,1.5,versicolor\n',
#  '6.1,2.8,4.7,1.2,versicolor\n',
#  '6.4,2.9,4.3,1.3,versicolor\n',
#  '6.6,3.0,4.4,1.4,versicolor\n',
#  '6.8,2.8,4.8,1.4,versicolor\n',
#  '6.7,3.0,5.0,1.7,versicolor\n',
#  '6.0,2.9,4.5,1.5,versicolor\n',
#  '5.7,2.6,3.5,1.0,versicolor\n',
#  '5.5,2.4,3.8,1.1,versicolor\n',
#  '5.5,2.4,3.7,1.0,versicolor\n',
#  '5.8,2.7,3.9,1.2,versicolor\n',
#  '6.0,2.7,5.1,1.6,versicolor\n',
#  '5.4,3.0,4.5,1.5,versicolor\n',
#  '6.0,3.4,4.5,1.6,versicolor\n',
#  '6.7,3.1,4.7,1.5,versicolor\n',
#  '6.3,2.3,4.4,1.3,versicolor\n',
#  '5.6,3.0,4.1,1.3,versicolor\n',
#  '5.5,2.5,4.0,1.3,versicolor\n',
#  '5.5,2.6,4.4,1.2,versicolor\n',
#  '6.1,3.0,4.6,1.4,versicolor\n',
#  '5.8,2.6,4.0,1.2,versicolor\n',
#  '5.0,2.3,3.3,1.0,versicolor\n',
#  '5.6,2.7,4.2,1.3,versicolor\n',
#  '5.7,3.0,4.2,1.2,versicolor\n',
#  '5.7,2.9,4.2,1.3,versicolor\n',
#  '6.2,2.9,4.3,1.3,versicolor\n',
#  '5.1,2.5,3.0,1.1,versicolor\n',
#  '5.7,2.8,4.1,1.3,versicolor\n',
#  '6.3,3.3,6.0,2.5,virginica\n',
#  '5.8,2.7,5.1,1.9,virginica\n',
#  '7.1,3.0,5.9,2.1,virginica\n',
#  '6.3,2.9,5.6,1.8,virginica\n',
#  '6.5,3.0,5.8,2.2,virginica\n',
#  '7.6,3.0,6.6,2.1,virginica\n',
#  '4.9,2.5,4.5,1.7,virginica\n',
#  '7.3,2.9,6.3,1.8,virginica\n',
#  '6.7,2.5,5.8,1.8,virginica\n',
#  '7.2,3.6,6.1,2.5,virginica\n',
#  '6.5,3.2,5.1,2.0,virginica\n',
#  '6.4,2.7,5.3,1.9,virginica\n',
#  '6.8,3.0,5.5,2.1,virginica\n',
#  '5.7,2.5,5.0,2.0,virginica\n',
#  '5.8,2.8,5.1,2.4,virginica\n',
#  '6.4,3.2,5.3,2.3,virginica\n',
#  '6.5,3.0,5.5,1.8,virginica\n',
#  '7.7,3.8,6.7,2.2,virginica\n',
#  '7.7,2.6,6.9,2.3,virginica\n',
#  '6.0,2.2,5.0,1.5,virginica\n',
#  '6.9,3.2,5.7,2.3,virginica\n',
#  '5.6,2.8,4.9,2.0,virginica\n',
#  '7.7,2.8,6.7,2.0,virginica\n',
#  '6.3,2.7,4.9,1.8,virginica\n',
#  '6.7,3.3,5.7,2.1,virginica\n',
#  '7.2,3.2,6.0,1.8,virginica\n',
#  '6.2,2.8,4.8,1.8,virginica\n',
#  '6.1,3.0,4.9,1.8,virginica\n',
#  '6.4,2.8,5.6,2.1,virginica\n',
#  '7.2,3.0,5.8,1.6,virginica\n',
#  '7.4,2.8,6.1,1.9,virginica\n',
#  '7.9,3.8,6.4,2.0,virginica\n',
#  '6.4,2.8,5.6,2.2,virginica\n',
#  '6.3,2.8,5.1,1.5,virginica\n',
#  '6.1,2.6,5.6,1.4,virginica\n',
#  '7.7,3.0,6.1,2.3,virginica\n',
#  '6.3,3.4,5.6,2.4,virginica\n',
#  '6.4,3.1,5.5,1.8,virginica\n',
#  '6.0,3.0,4.8,1.8,virginica\n',
#  '6.9,3.1,5.4,2.1,virginica\n',
#  '6.7,3.1,5.6,2.4,virginica\n',
#  '6.9,3.1,5.1,2.3,virginica\n',
#  '5.8,2.7,5.1,1.9,virginica\n',
#  '6.8,3.2,5.9,2.3,virginica\n',
#  '6.7,3.3,5.7,2.5,virginica\n',
#  '6.7,3.0,5.2,2.3,virginica\n',
#  '6.3,2.5,5.0,1.9,virginica\n',
#  '6.5,3.0,5.2,2.0,virginica\n',
#  '6.2,3.4,5.4,2.3,virginica\n',
#  '5.9,3.0,5.1,1.8,virginica\n']

# %% [markdown]
# We can interact through the lines of the file and make some operations.
# Lets divide the dataset into three independent datasets: one for each type of flower.
#
# We will:
# - Opend the files for read/write/append
# - Iterate though lines
# - Check the content of the line for the name of the flower
# - Append the new data to the respective file
# - Close the files

# %%
### input file
f = open("..\data\iris.csv",'r')

# %%
### output file
setosa = open("setosa.csv","a")
versicolor = open("versicolor.csv","a")
virginica = open("virginica.csv","a")

# %%
### read the first line that has the column names
names = f.readline()
print(names)
# Out:
# sepal_length,sepal_width,petal_length,petal_width,species

# %%
### write the column names into each of the three files
setosa.write(names)
versicolor.write(names)
virginica.write(names)
# Out:
# 58

# %%
iris = f.readlines()
for line in iris:
    if "setosa" in line:
        print("Setosa is in %s" % line)
        setosa.write(line)
    elif "versicolor" in line:
        print("Versicolor is in %s" % line)
        versicolor.write(line)
    else:
        print("Virginica is in %s" % line)
        virginica.write(line)
# Out:
# Setosa is in 5.1,3.5,1.4,0.2,setosa
#
# Setosa is in 4.9,3.0,1.4,0.2,setosa
#
# Setosa is in 4.7,3.2,1.3,0.2,setosa
#
# Setosa is in 4.6,3.1,1.5,0.2,setosa
#
# Setosa is in 5.0,3.6,1.4,0.2,setosa
#
# Setosa is in 5.4,3.9,1.7,0.4,setosa
#
# Setosa is in 4.6,3.4,1.4,0.3,setosa
#
# Setosa is in 5.0,3.4,1.5,0.2,setosa
#
# Setosa is in 4.4,2.9,1.4,0.2,setosa
#
# Setosa is in 4.9,3.1,1.5,0.1,setosa
#
# Setosa is in 5.4,3.7,1.5,0.2,setosa
#
# Setosa is in 4.8,3.4,1.6,0.2,setosa
#
# Setosa is in 4.8,3.0,1.4,0.1,setosa
#
# Setosa is in 4.3,3.0,1.1,0.1,setosa
#
# Setosa is in 5.8,4.0,1.2,0.2,setosa
#
# Setosa is in 5.7,4.4,1.5,0.4,setosa
#
# Setosa is in 5.4,3.9,1.3,0.4,setosa
#
# Setosa is in 5.1,3.5,1.4,0.3,setosa
#
# Setosa is in 5.7,3.8,1.7,0.3,setosa
#
# Setosa is in 5.1,3.8,1.5,0.3,setosa
#
# Setosa is in 5.4,3.4,1.7,0.2,setosa
#
# Setosa is in 5.1,3.7,1.5,0.4,setosa
#
# Setosa is in 4.6,3.6,1.0,0.2,setosa
#
# Setosa is in 5.1,3.3,1.7,0.5,setosa
#
# Setosa is in 4.8,3.4,1.9,0.2,setosa
#
# Setosa is in 5.0,3.0,1.6,0.2,setosa
#
# Setosa is in 5.0,3.4,1.6,0.4,setosa
#
# Setosa is in 5.2,3.5,1.5,0.2,setosa
#
# Setosa is in 5.2,3.4,1.4,0.2,setosa
#
# Setosa is in 4.7,3.2,1.6,0.2,setosa
#
# Setosa is in 4.8,3.1,1.6,0.2,setosa
#
# Setosa is in 5.4,3.4,1.5,0.4,setosa
#
# Setosa is in 5.2,4.1,1.5,0.1,setosa
#
# Setosa is in 5.5,4.2,1.4,0.2,setosa
#
# Setosa is in 4.9,3.1,1.5,0.1,setosa
#
# Setosa is in 5.0,3.2,1.2,0.2,setosa
#
# Setosa is in 5.5,3.5,1.3,0.2,setosa
#
# Setosa is in 4.9,3.1,1.5,0.1,setosa
#
# Setosa is in 4.4,3.0,1.3,0.2,setosa
#
# Setosa is in 5.1,3.4,1.5,0.2,setosa
#
# Setosa is in 5.0,3.5,1.3,0.3,setosa
#
# Setosa is in 4.5,2.3,1.3,0.3,setosa
#
# Setosa is in 4.4,3.2,1.3,0.2,setosa
#
# Setosa is in 5.0,3.5,1.6,0.6,setosa
#
# Setosa is in 5.1,3.8,1.9,0.4,setosa
#
# Setosa is in 4.8,3.0,1.4,0.3,setosa
#
# Setosa is in 5.1,3.8,1.6,0.2,setosa
#
# Setosa is in 4.6,3.2,1.4,0.2,setosa
#
# Setosa is in 5.3,3.7,1.5,0.2,setosa
#
# Setosa is in 5.0,3.3,1.4,0.2,setosa
#
# Versicolor is in 7.0,3.2,4.7,1.4,versicolor
#
# Versicolor is in 6.4,3.2,4.5,1.5,versicolor
#
# Versicolor is in 6.9,3.1,4.9,1.5,versicolor
#
# Versicolor is in 5.5,2.3,4.0,1.3,versicolor
#
# Versicolor is in 6.5,2.8,4.6,1.5,versicolor
#
# Versicolor is in 5.7,2.8,4.5,1.3,versicolor
#
# Versicolor is in 6.3,3.3,4.7,1.6,versicolor
#
# Versicolor is in 4.9,2.4,3.3,1.0,versicolor
#
# Versicolor is in 6.6,2.9,4.6,1.3,versicolor
#
# Versicolor is in 5.2,2.7,3.9,1.4,versicolor
#
# Versicolor is in 5.0,2.0,3.5,1.0,versicolor
#
# Versicolor is in 5.9,3.0,4.2,1.5,versicolor
#
# Versicolor is in 6.0,2.2,4.0,1.0,versicolor
#
# Versicolor is in 6.1,2.9,4.7,1.4,versicolor
#
# Versicolor is in 5.6,2.9,3.6,1.3,versicolor
#
# Versicolor is in 6.7,3.1,4.4,1.4,versicolor
#
# Versicolor is in 5.6,3.0,4.5,1.5,versicolor
#
# Versicolor is in 5.8,2.7,4.1,1.0,versicolor
#
# Versicolor is in 6.2,2.2,4.5,1.5,versicolor
#
# Versicolor is in 5.6,2.5,3.9,1.1,versicolor
#
# Versicolor is in 5.9,3.2,4.8,1.8,versicolor
#
# Versicolor is in 6.1,2.8,4.0,1.3,versicolor
#
# Versicolor is in 6.3,2.5,4.9,1.5,versicolor
#
# Versicolor is in 6.1,2.8,4.7,1.2,versicolor
#
# Versicolor is in 6.4,2.9,4.3,1.3,versicolor
#
# Versicolor is in 6.6,3.0,4.4,1.4,versicolor
#
# Versicolor is in 6.8,2.8,4.8,1.4,versicolor
#
# Versicolor is in 6.7,3.0,5.0,1.7,versicolor
#
# Versicolor is in 6.0,2.9,4.5,1.5,versicolor
#
# Versicolor is in 5.7,2.6,3.5,1.0,versicolor
#
# Versicolor is in 5.5,2.4,3.8,1.1,versicolor
#
# Versicolor is in 5.5,2.4,3.7,1.0,versicolor
#
# Versicolor is in 5.8,2.7,3.9,1.2,versicolor
#
# Versicolor is in 6.0,2.7,5.1,1.6,versicolor
#
# Versicolor is in 5.4,3.0,4.5,1.5,versicolor
#
# Versicolor is in 6.0,3.4,4.5,1.6,versicolor
#
# Versicolor is in 6.7,3.1,4.7,1.5,versicolor
#
# Versicolor is in 6.3,2.3,4.4,1.3,versicolor
#
# Versicolor is in 5.6,3.0,4.1,1.3,versicolor
#
# Versicolor is in 5.5,2.5,4.0,1.3,versicolor
#
# Versicolor is in 5.5,2.6,4.4,1.2,versicolor
#
# Versicolor is in 6.1,3.0,4.6,1.4,versicolor
#
# Versicolor is in 5.8,2.6,4.0,1.2,versicolor
#
# Versicolor is in 5.0,2.3,3.3,1.0,versicolor
#
# Versicolor is in 5.6,2.7,4.2,1.3,versicolor
#
# Versicolor is in 5.7,3.0,4.2,1.2,versicolor
#
# Versicolor is in 5.7,2.9,4.2,1.3,versicolor
#
# Versicolor is in 6.2,2.9,4.3,1.3,versicolor
#
# Versicolor is in 5.1,2.5,3.0,1.1,versicolor
#
# Versicolor is in 5.7,2.8,4.1,1.3,versicolor
#
# Virginica is in 6.3,3.3,6.0,2.5,virginica
#
# Virginica is in 5.8,2.7,5.1,1.9,virginica
#
# Virginica is in 7.1,3.0,5.9,2.1,virginica
#
# Virginica is in 6.3,2.9,5.6,1.8,virginica
#
# Virginica is in 6.5,3.0,5.8,2.2,virginica
#
# Virginica is in 7.6,3.0,6.6,2.1,virginica
#
# Virginica is in 4.9,2.5,4.5,1.7,virginica
#
# Virginica is in 7.3,2.9,6.3,1.8,virginica
#
# Virginica is in 6.7,2.5,5.8,1.8,virginica
#
# Virginica is in 7.2,3.6,6.1,2.5,virginica
#
# Virginica is in 6.5,3.2,5.1,2.0,virginica
#
# Virginica is in 6.4,2.7,5.3,1.9,virginica
#
# Virginica is in 6.8,3.0,5.5,2.1,virginica
#
# Virginica is in 5.7,2.5,5.0,2.0,virginica
#
# Virginica is in 5.8,2.8,5.1,2.4,virginica
#
# Virginica is in 6.4,3.2,5.3,2.3,virginica
#
# Virginica is in 6.5,3.0,5.5,1.8,virginica
#
# Virginica is in 7.7,3.8,6.7,2.2,virginica
#
# Virginica is in 7.7,2.6,6.9,2.3,virginica
#
# Virginica is in 6.0,2.2,5.0,1.5,virginica
#
# Virginica is in 6.9,3.2,5.7,2.3,virginica
#
# Virginica is in 5.6,2.8,4.9,2.0,virginica
#
# Virginica is in 7.7,2.8,6.7,2.0,virginica
#
# Virginica is in 6.3,2.7,4.9,1.8,virginica
#
# Virginica is in 6.7,3.3,5.7,2.1,virginica
#
# Virginica is in 7.2,3.2,6.0,1.8,virginica
#
# Virginica is in 6.2,2.8,4.8,1.8,virginica
#
# Virginica is in 6.1,3.0,4.9,1.8,virginica
#
# Virginica is in 6.4,2.8,5.6,2.1,virginica
#
# Virginica is in 7.2,3.0,5.8,1.6,virginica
#
# Virginica is in 7.4,2.8,6.1,1.9,virginica
#
# Virginica is in 7.9,3.8,6.4,2.0,virginica
#
# Virginica is in 6.4,2.8,5.6,2.2,virginica
#
# Virginica is in 6.3,2.8,5.1,1.5,virginica
#
# Virginica is in 6.1,2.6,5.6,1.4,virginica
#
# Virginica is in 7.7,3.0,6.1,2.3,virginica
#
# Virginica is in 6.3,3.4,5.6,2.4,virginica
#
# Virginica is in 6.4,3.1,5.5,1.8,virginica
#
# Virginica is in 6.0,3.0,4.8,1.8,virginica
#
# Virginica is in 6.9,3.1,5.4,2.1,virginica
#
# Virginica is in 6.7,3.1,5.6,2.4,virginica
#
# Virginica is in 6.9,3.1,5.1,2.3,virginica
#
# Virginica is in 5.8,2.7,5.1,1.9,virginica
#
# Virginica is in 6.8,3.2,5.9,2.3,virginica
#
# Virginica is in 6.7,3.3,5.7,2.5,virginica
#
# Virginica is in 6.7,3.0,5.2,2.3,virginica
#
# Virginica is in 6.3,2.5,5.0,1.9,virginica
#
# Virginica is in 6.5,3.0,5.2,2.0,virginica
#
# Virginica is in 6.2,3.4,5.4,2.3,virginica
#
# Virginica is in 5.9,3.0,5.1,1.8,virginica

# %%
### close the connection of the files
setosa.close()
versicolor.close()
virginica.close()

# %% [markdown]
# Another way to read the content of a file is as follows:

# %%
with open('..\data\iris.csv','r') as f:
    data = f.read()
    
data
# Out:
# 'sepal_length,sepal_width,petal_length,petal_width,species\n5.1,3.5,1.4,0.2,setosa\n4.9,3.0,1.4,0.2,setosa\n4.7,3.2,1.3,0.2,setosa\n4.6,3.1,1.5,0.2,setosa\n5.0,3.6,1.4,0.2,setosa\n5.4,3.9,1.7,0.4,setosa\n4.6,3.4,1.4,0.3,setosa\n5.0,3.4,1.5,0.2,setosa\n4.4,2.9,1.4,0.2,setosa\n4.9,3.1,1.5,0.1,setosa\n5.4,3.7,1.5,0.2,setosa\n4.8,3.4,1.6,0.2,setosa\n4.8,3.0,1.4,0.1,setosa\n4.3,3.0,1.1,0.1,setosa\n5.8,4.0,1.2,0.2,setosa\n5.7,4.4,1.5,0.4,setosa\n5.4,3.9,1.3,0.4,setosa\n5.1,3.5,1.4,0.3,setosa\n5.7,3.8,1.7,0.3,setosa\n5.1,3.8,1.5,0.3,setosa\n5.4,3.4,1.7,0.2,setosa\n5.1,3.7,1.5,0.4,setosa\n4.6,3.6,1.0,0.2,setosa\n5.1,3.3,1.7,0.5,setosa\n4.8,3.4,1.9,0.2,setosa\n5.0,3.0,1.6,0.2,setosa\n5.0,3.4,1.6,0.4,setosa\n5.2,3.5,1.5,0.2,setosa\n5.2,3.4,1.4,0.2,setosa\n4.7,3.2,1.6,0.2,setosa\n4.8,3.1,1.6,0.2,setosa\n5.4,3.4,1.5,0.4,setosa\n5.2,4.1,1.5,0.1,setosa\n5.5,4.2,1.4,0.2,setosa\n4.9,3.1,1.5,0.1,setosa\n5.0,3.2,1.2,0.2,setosa\n5.5,3.5,1.3,0.2,setosa\n4.9,3.1,1.5,0.1,setosa\n4.4,3.0,1.3,0.2,setosa\n5.1,3.4,1.5,0.2,setosa\n5.0,3.5,1.3,0.3,setosa\n4.5,2.3,1.3,0.3,setosa\n4.4,3.2,1.3,0.2,setosa\n5.0,3.5,1.6,0.6,setosa\n5.1,3.8,1.9,0.4,setosa\n4.8,3.0,1.4,0.3,setosa\n5.1,3.8,1.6,0.2,setosa\n4.6,3.2,1.4,0.2,setosa\n5.3,3.7,1.5,0.2,setosa\n5.0,3.3,1.4,0.2,setosa\n7.0,3.2,4.7,1.4,versicolor\n6.4,3.2,4.5,1.5,versicolor\n6.9,3.1,4.9,1.5,versicolor\n5.5,2.3,4.0,1.3,versicolor\n6.5,2.8,4.6,1.5,versicolor\n5.7,2.8,4.5,1.3,versicolor\n6.3,3.3,4.7,1.6,versicolor\n4.9,2.4,3.3,1.0,versicolor\n6.6,2.9,4.6,1.3,versicolor\n5.2,2.7,3.9,1.4,versicolor\n5.0,2.0,3.5,1.0,versicolor\n5.9,3.0,4.2,1.5,versicolor\n6.0,2.2,4.0,1.0,versicolor\n6.1,2.9,4.7,1.4,versicolor\n5.6,2.9,3.6,1.3,versicolor\n6.7,3.1,4.4,1.4,versicolor\n5.6,3.0,4.5,1.5,versicolor\n5.8,2.7,4.1,1.0,versicolor\n6.2,2.2,4.5,1.5,versicolor\n5.6,2.5,3.9,1.1,versicolor\n5.9,3.2,4.8,1.8,versicolor\n6.1,2.8,4.0,1.3,versicolor\n6.3,2.5,4.9,1.5,versicolor\n6.1,2.8,4.7,1.2,versicolor\n6.4,2.9,4.3,1.3,versicolor\n6.6,3.0,4.4,1.4,versicolor\n6.8,2.8,4.8,1.4,versicolor\n6.7,3.0,5.0,1.7,versicolor\n6.0,2.9,4.5,1.5,versicolor\n5.7,2.6,3.5,1.0,versicolor\n5.5,2.4,3.8,1.1,versicolor\n5.5,2.4,3.7,1.0,versicolor\n5.8,2.7,3.9,1.2,versicolor\n6.0,2.7,5.1,1.6,versicolor\n5.4,3.0,4.5,1.5,versicolor\n6.0,3.4,4.5,1.6,versicolor\n6.7,3.1,4.7,1.5,versicolor\n6.3,2.3,4.4,1.3,versicolor\n5.6,3.0,4.1,1.3,versicolor\n5.5,2.5,4.0,1.3,versicolor\n5.5,2.6,4.4,1.2,versicolor\n6.1,3.0,4.6,1.4,versicolor\n5.8,2.6,4.0,1.2,versicolor\n5.0,2.3,3.3,1.0,versicolor\n5.6,2.7,4.2,1.3,versicolor\n5.7,3.0,4.2,1.2,versicolor\n5.7,2.9,4.2,1.3,versicolor\n6.2,2.9,4.3,1.3,versicolor\n5.1,2.5,3.0,1.1,versicolor\n5.7,2.8,4.1,1.3,versicolor\n6.3,3.3,6.0,2.5,virginica\n5.8,2.7,5.1,1.9,virginica\n7.1,3.0,5.9,2.1,virginica\n6.3,2.9,5.6,1.8,virginica\n6.5,3.0,5.8,2.2,virginica\n7.6,3.0,6.6,2.1,virginica\n4.9,2.5,4.5,1.7,virginica\n7.3,2.9,6.3,1.8,virginica\n6.7,2.5,5.8,1.8,virginica\n7.2,3.6,6.1,2.5,virginica\n6.5,3.2,5.1,2.0,virginica\n6.4,2.7,5.3,1.9,virginica\n6.8,3.0,5.5,2.1,virginica\n5.7,2.5,5.0,2.0,virginica\n5.8,2.8,5.1,2.4,virginica\n6.4,3.2,5.3,2.3,virginica\n6.5,3.0,5.5,1.8,virginica\n7.7,3.8,6.7,2.2,virginica\n7.7,2.6,6.9,2.3,virginica\n6.0,2.2,5.0,1.5,virginica\n6.9,3.2,5.7,2.3,virginica\n5.6,2.8,4.9,2.0,virginica\n7.7,2.8,6.7,2.0,virginica\n6.3,2.7,4.9,1.8,virginica\n6.7,3.3,5.7,2.1,virginica\n7.2,3.2,6.0,1.8,virginica\n6.2,2.8,4.8,1.8,virginica\n6.1,3.0,4.9,1.8,virginica\n6.4,2.8,5.6,2.1,virginica\n7.2,3.0,5.8,1.6,virginica\n7.4,2.8,6.1,1.9,virginica\n7.9,3.8,6.4,2.0,virginica\n6.4,2.8,5.6,2.2,virginica\n6.3,2.8,5.1,1.5,virginica\n6.1,2.6,5.6,1.4,virginica\n7.7,3.0,6.1,2.3,virginica\n6.3,3.4,5.6,2.4,virginica\n6.4,3.1,5.5,1.8,virginica\n6.0,3.0,4.8,1.8,virginica\n6.9,3.1,5.4,2.1,virginica\n6.7,3.1,5.6,2.4,virginica\n6.9,3.1,5.1,2.3,virginica\n5.8,2.7,5.1,1.9,virginica\n6.8,3.2,5.9,2.3,virginica\n6.7,3.3,5.7,2.5,virginica\n6.7,3.0,5.2,2.3,virginica\n6.3,2.5,5.0,1.9,virginica\n6.5,3.0,5.2,2.0,virginica\n6.2,3.4,5.4,2.3,virginica\n5.9,3.0,5.1,1.8,v ...

# %%
data.split('\n')
# Out:
# ['sepal_length,sepal_width,petal_length,petal_width,species',
#  '5.1,3.5,1.4,0.2,setosa',
#  '4.9,3.0,1.4,0.2,setosa',
#  '4.7,3.2,1.3,0.2,setosa',
#  '4.6,3.1,1.5,0.2,setosa',
#  '5.0,3.6,1.4,0.2,setosa',
#  '5.4,3.9,1.7,0.4,setosa',
#  '4.6,3.4,1.4,0.3,setosa',
#  '5.0,3.4,1.5,0.2,setosa',
#  '4.4,2.9,1.4,0.2,setosa',
#  '4.9,3.1,1.5,0.1,setosa',
#  '5.4,3.7,1.5,0.2,setosa',
#  '4.8,3.4,1.6,0.2,setosa',
#  '4.8,3.0,1.4,0.1,setosa',
#  '4.3,3.0,1.1,0.1,setosa',
#  '5.8,4.0,1.2,0.2,setosa',
#  '5.7,4.4,1.5,0.4,setosa',
#  '5.4,3.9,1.3,0.4,setosa',
#  '5.1,3.5,1.4,0.3,setosa',
#  '5.7,3.8,1.7,0.3,setosa',
#  '5.1,3.8,1.5,0.3,setosa',
#  '5.4,3.4,1.7,0.2,setosa',
#  '5.1,3.7,1.5,0.4,setosa',
#  '4.6,3.6,1.0,0.2,setosa',
#  '5.1,3.3,1.7,0.5,setosa',
#  '4.8,3.4,1.9,0.2,setosa',
#  '5.0,3.0,1.6,0.2,setosa',
#  '5.0,3.4,1.6,0.4,setosa',
#  '5.2,3.5,1.5,0.2,setosa',
#  '5.2,3.4,1.4,0.2,setosa',
#  '4.7,3.2,1.6,0.2,setosa',
#  '4.8,3.1,1.6,0.2,setosa',
#  '5.4,3.4,1.5,0.4,setosa',
#  '5.2,4.1,1.5,0.1,setosa',
#  '5.5,4.2,1.4,0.2,setosa',
#  '4.9,3.1,1.5,0.1,setosa',
#  '5.0,3.2,1.2,0.2,setosa',
#  '5.5,3.5,1.3,0.2,setosa',
#  '4.9,3.1,1.5,0.1,setosa',
#  '4.4,3.0,1.3,0.2,setosa',
#  '5.1,3.4,1.5,0.2,setosa',
#  '5.0,3.5,1.3,0.3,setosa',
#  '4.5,2.3,1.3,0.3,setosa',
#  '4.4,3.2,1.3,0.2,setosa',
#  '5.0,3.5,1.6,0.6,setosa',
#  '5.1,3.8,1.9,0.4,setosa',
#  '4.8,3.0,1.4,0.3,setosa',
#  '5.1,3.8,1.6,0.2,setosa',
#  '4.6,3.2,1.4,0.2,setosa',
#  '5.3,3.7,1.5,0.2,setosa',
#  '5.0,3.3,1.4,0.2,setosa',
#  '7.0,3.2,4.7,1.4,versicolor',
#  '6.4,3.2,4.5,1.5,versicolor',
#  '6.9,3.1,4.9,1.5,versicolor',
#  '5.5,2.3,4.0,1.3,versicolor',
#  '6.5,2.8,4.6,1.5,versicolor',
#  '5.7,2.8,4.5,1.3,versicolor',
#  '6.3,3.3,4.7,1.6,versicolor',
#  '4.9,2.4,3.3,1.0,versicolor',
#  '6.6,2.9,4.6,1.3,versicolor',
#  '5.2,2.7,3.9,1.4,versicolor',
#  '5.0,2.0,3.5,1.0,versicolor',
#  '5.9,3.0,4.2,1.5,versicolor',
#  '6.0,2.2,4.0,1.0,versicolor',
#  '6.1,2.9,4.7,1.4,versicolor',
#  '5.6,2.9,3.6,1.3,versicolor',
#  '6.7,3.1,4.4,1.4,versicolor',
#  '5.6,3.0,4.5,1.5,versicolor',
#  '5.8,2.7,4.1,1.0,versicolor',
#  '6.2,2.2,4.5,1.5,versicolor',
#  '5.6,2.5,3.9,1.1,versicolor',
#  '5.9,3.2,4.8,1.8,versicolor',
#  '6.1,2.8,4.0,1.3,versicolor',
#  '6.3,2.5,4.9,1.5,versicolor',
#  '6.1,2.8,4.7,1.2,versicolor',
#  '6.4,2.9,4.3,1.3,versicolor',
#  '6.6,3.0,4.4,1.4,versicolor',
#  '6.8,2.8,4.8,1.4,versicolor',
#  '6.7,3.0,5.0,1.7,versicolor',
#  '6.0,2.9,4.5,1.5,versicolor',
#  '5.7,2.6,3.5,1.0,versicolor',
#  '5.5,2.4,3.8,1.1,versicolor',
#  '5.5,2.4,3.7,1.0,versicolor',
#  '5.8,2.7,3.9,1.2,versicolor',
#  '6.0,2.7,5.1,1.6,versicolor',
#  '5.4,3.0,4.5,1.5,versicolor',
#  '6.0,3.4,4.5,1.6,versicolor',
#  '6.7,3.1,4.7,1.5,versicolor',
#  '6.3,2.3,4.4,1.3,versicolor',
#  '5.6,3.0,4.1,1.3,versicolor',
#  '5.5,2.5,4.0,1.3,versicolor',
#  '5.5,2.6,4.4,1.2,versicolor',
#  '6.1,3.0,4.6,1.4,versicolor',
#  '5.8,2.6,4.0,1.2,versicolor',
#  '5.0,2.3,3.3,1.0,versicolor',
#  '5.6,2.7,4.2,1.3,versicolor',
#  '5.7,3.0,4.2,1.2,versicolor',
#  '5.7,2.9,4.2,1.3,versicolor',
#  '6.2,2.9,4.3,1.3,versicolor',
#  '5.1,2.5,3.0,1.1,versicolor',
#  '5.7,2.8,4.1,1.3,versicolor',
#  '6.3,3.3,6.0,2.5,virginica',
#  '5.8,2.7,5.1,1.9,virginica',
#  '7.1,3.0,5.9,2.1,virginica',
#  '6.3,2.9,5.6,1.8,virginica',
#  '6.5,3.0,5.8,2.2,virginica',
#  '7.6,3.0,6.6,2.1,virginica',
#  '4.9,2.5,4.5,1.7,virginica',
#  '7.3,2.9,6.3,1.8,virginica',
#  '6.7,2.5,5.8,1.8,virginica',
#  '7.2,3.6,6.1,2.5,virginica',
#  '6.5,3.2,5.1,2.0,virginica',
#  '6.4,2.7,5.3,1.9,virginica',
#  '6.8,3.0,5.5,2.1,virginica',
#  '5.7,2.5,5.0,2.0,virginica',
#  '5.8,2.8,5.1,2.4,virginica',
#  '6.4,3.2,5.3,2.3,virginica',
#  '6.5,3.0,5.5,1.8,virginica',
#  '7.7,3.8,6.7,2.2,virginica',
#  '7.7,2.6,6.9,2.3,virginica',
#  '6.0,2.2,5.0,1.5,virginica',
#  '6.9,3.2,5.7,2.3,virginica',
#  '5.6,2.8,4.9,2.0,virginica',
#  '7.7,2.8,6.7,2.0,virginica',
#  '6.3,2.7,4.9,1.8,virginica',
#  '6.7,3.3,5.7,2.1,virginica',
#  '7.2,3.2,6.0,1.8,virginica',
#  '6.2,2.8,4.8,1.8,virginica',
#  '6.1,3.0,4.9,1.8,virginica',
#  '6.4,2.8,5.6,2.1,virginica',
#  '7.2,3.0,5.8,1.6,virginica',
#  '7.4,2.8,6.1,1.9,virginica',
#  '7.9,3.8,6.4,2.0,virginica',
#  '6.4,2.8,5.6,2.2,virginica',
#  '6.3,2.8,5.1,1.5,virginica',
#  '6.1,2.6,5.6,1.4,virginica',
#  '7.7,3.0,6.1,2.3,virginica',
#  '6.3,3.4,5.6,2.4,virginica',
#  '6.4,3.1,5.5,1.8,virginica',
#  '6.0,3.0,4.8,1.8,virginica',
#  '6.9,3.1,5.4,2.1,virginica',
#  '6.7,3.1,5.6,2.4,virginica',
#  '6.9,3.1,5.1,2.3,virginica',
#  '5.8,2.7,5.1,1.9,virginica',
#  '6.8,3.2,5.9,2.3,virginica',
#  '6.7,3.3,5.7,2.5,virginica',
#  '6.7,3.0,5.2,2.3,virginica',
#  '6.3,2.5,5.0,1.9,virginica',
#  '6.5,3.0,5.2,2.0,virginica',
#  '6.2,3.4,5.4,2.3,virginica',
#  '5.9,3.0,5.1,1.8,virginica',
#  '']

# %% [markdown]
# # DataBase connections
#
# ## ODBC

# %%
import pyodbc 
cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=WIN10\TCDS;"
                      "Database=COLLEGE;"
                      "Trusted_Connection=yes;")

# %%
cursor = cnxn.cursor()
cursor.execute('SELECT * FROM Departments')

for row in cursor:
    print('row = %r' % (row,))
# Out:
# row = (1, 'English')
# row = (2, 'Science')
# row = (3, 'Arts')
# row = (4, 'Sport')

# %%
# get the list one by one
cursor.execute("SELECT * FROM Teachers;") 
row = cursor.fetchone() 
while row: 
    print(row )
    row = cursor.fetchone()
# Out:
# (1, 'Kaylea', 'Monzingo', 'F')
# (2, 'Amanda', 'Dworkin', 'F')
# (3, 'Jordyn', 'Baron', 'F')
# (4, 'Katherine', 'Dibari', 'F')
# (5, 'Heather', 'Metcalf', 'F')
# (6, 'Madison', 'Batan', 'F')
# (7, 'Cortnee', 'Kinderknecht', 'F')
# (8, 'Caroline', 'Knuesel', 'F')
# (9, 'Katerina', 'Young', 'F')
# (10, 'Mackenzie', 'Olsen', 'F')
# (11, 'Kaitlin', 'Delude', 'F')
# (12, 'Mikayla', 'Russell', 'F')
# (13, 'Alexander', 'Watts', 'M')
# (14, 'Jeffrey', 'Batzel', 'M')
# (15, 'Conor', 'Mckittrick', 'M')
# (16, 'Robert', 'Aivazian', 'M')
# (17, 'Tanner', 'Fitzsimons', 'M')
# (18, 'Daniel', 'Bland', 'M')
# (19, 'Terran', 'Beaty', 'M')
# (20, 'Zachary', 'Healy', 'M')
# (21, 'Ernest', 'Stoyanov', 'M')
# (22, 'Darick', 'Hess', 'M')
# (23, 'Maxwell', 'Romkee', 'M')
# (24, 'Keegan', 'Price', 'M')

# %%
### get the first 5 records
cursor.execute("SELECT * FROM Courses;") 
row = cursor.fetchmany(5) 
print(row)
# Out:
# [(1, 'English Begginers', 1, 15), (2, 'Advanced English', 1, 15), (3, 'Proffesional English', 1, 15), (4, 'Mathematics 101', 2, 2), (5, 'Matematics Advanced', 2, 13)]

# %%
### get all records
cursor.execute("SELECT * FROM Courses;") 
row = cursor.fetchall() 

print(row)
# Out:
# [(1, 'English Begginers', 1, 15), (2, 'Advanced English', 1, 15), (3, 'Proffesional English', 1, 15), (4, 'Mathematics 101', 2, 2), (5, 'Matematics Advanced', 2, 13), (6, 'Algebra', 2, 13), (7, 'Geometry', 2, 13), (8, 'Chemistry', 2, 14), (9, 'Physics', 2, 13), (10, 'Biology', 2, 3), (11, 'Genetics', 2, 19), (12, 'Neurobiology', 2, 19), (13, 'Statistics', 2, 5), (14, 'Computer Science', 2, 1), (15, 'Data Science', 2, 10), (16, 'SQL', 2, 20), (17, 'Python', 2, 19), (18, 'R', 2, 17), (19, 'Java', 2, 22), (20, 'History of Arts', 3, 8), (21, 'Painting', 3, 9), (22, 'Sculpture', 3, 16), (23, 'Musicology', 3, 6), (24, 'Theater', 3, 21), (25, 'Literature', 3, 18), (26, 'Basketball', 4, 4), (27, 'Volleyball', 4, 11), (28, 'Football', 4, 7), (29, 'Tenis', 4, 24), (30, 'Swimming', 4, 12), (31, 'Gymnastics', 4, 23)]

# %% [markdown]
# #### Pass a SQL Table to a Pandas DataFrame

# %%
import pandas as pd
import pyodbc 

cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=WIN10\TCDS;"
                      "Database=COLLEGE;"
                      "Trusted_Connection=yes;")

df = pd.read_sql("SELECT * FROM Courses",cnxn)
df.head()
# Out:
#    CourseId            CourseName  DepartmentID  TeacherId
# 0         1     English Begginers             1         15
# 1         2      Advanced English             1         15
# 2         3  Proffesional English             1         15
# 3         4       Mathematics 101             2          2
# 4         5   Matematics Advanced             2         13

# %% [markdown]
# ## SQLite3

# %%
import sqlite3
conn = sqlite3.connect("tcds_example.db")
c = conn.cursor()

# %%
c.execute('''CREATE TABLE Proglangs (
             LangId INT,
             LangName VARCHAR(50),
             IsObjectOriented INT);''')

# %%
c.execute("INSERT INTO Proglangs VALUES (1,'Perl',1);")
c.execute("INSERT INTO Proglangs VALUES (2,'C',0);")
c.execute("INSERT INTO Proglangs VALUES (3,'Basic',0);")
c.execute("INSERT INTO Proglangs VALUES (4,'C++',1);")
c.execute("INSERT INTO Proglangs VALUES (5,'Java',1);")
c.execute("INSERT INTO Proglangs VALUES (6,'Python',1);")
c.execute("INSERT INTO Proglangs VALUES (7,'Rubi',1);")
c.execute("INSERT INTO Proglangs VALUES (8,'Pascal',0);")
c.execute("INSERT INTO Proglangs VALUES (9,'Fortrant',0);")
c.execute("INSERT INTO Proglangs VALUES (10,'Scheme',0);")
c.execute("INSERT INTO Proglangs VALUES (11,'Haskell',0);")
c.execute("INSERT INTO Proglangs VALUES (12,'PHP',1);")

# %%
c.execute("SELECT * FROM Proglangs")

# %%
### get the first row
print(c.fetchone())
# Out:
# (1, 'Perl', 1)

# %%
### get the next row
print(c.fetchone())
# Out:
# (2, 'C', 0)

# %%
### get the next row
print(c.fetchone())
# Out:
# (3, 'Basic', 0)

# %%
## get all the data in the table beginind from the cursor (cursor is now on the fourth row!)
print(c.fetchall())
# Out:
# [(4, 'C++', 1), (5, 'Java', 1), (6, 'Python', 1), (7, 'Rubi', 1), (8, 'Pascal', 0), (9, 'Fortrant', 0), (10, 'Scheme', 0), (11, 'Haskell', 0), (12, 'PHP', 1)]

# %%
### print the rows obtined from a specific query
for row in c.execute("SELECT * FROM Proglangs WHERE IsObjectOriented = 1"):
    print(row)
# Out:
# (1, 'Perl', 1)
# (4, 'C++', 1)
# (5, 'Java', 1)
# (6, 'Python', 1)
# (7, 'Rubi', 1)
# (12, 'PHP', 1)

# %% [markdown]
# # Regular Expressions in Python
#
#
#
# <img src="https://i.pinimg.com/originals/19/44/b1/1944b14175b0136b578287c0169a5c69.png" width='318' height='450' style='float: left;'></img>

# %%
import re

# %%
str = '''
Name: Mr. Peter Johns
eMail: peter@gmail.com
Phone: (54)-333-25-22

Name: Mrs. Mary Green
eMail: mary@yahoo.com
Phone: (50)-231-00-19

Name: Mr. George Brown
eMail: gbrn@bbb.com
Phone: (49)-882-55-51
'''

# %%
#str='abc@example.com'
match=re.search(r'\w+@\w+.\w+',str) #return abc@example.com

match
# Out:
# <_sre.SRE_Match object; span=(30, 45), match='peter@gmail.com'>

# %%
#num='555-555-5555'
match_num=re.search(r'(\W\d{2}\W.\d{3}.\d{2}.\d{2})',str) 
match_num
# Out:
# <_sre.SRE_Match object; span=(53, 67), match='(54)-333-25-22'>

# %%
### Print eMails
pattern = re.compile(r'\w+@\w+.\w+')
matches = pattern.finditer(str)

matches

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(30, 45), match='peter@gmail.com'>
# <_sre.SRE_Match object; span=(98, 112), match='mary@yahoo.com'>
# <_sre.SRE_Match object; span=(166, 178), match='gbrn@bbb.com'>

# %%
### Print phone numbers
pattern = re.compile(r'(\W\d{2}\W.\d{3}.\d{2}.\d{2})')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(53, 67), match='(54)-333-25-22'>
# <_sre.SRE_Match object; span=(120, 134), match='(50)-231-00-19'>
# <_sre.SRE_Match object; span=(186, 200), match='(49)-882-55-51'>

# %%
### Print the names of the males (Mr.) in the list
### The ? sign indicates that the point is optional
pattern = re.compile(r'Mr\.?\s[A-Z]\w*\s[A-Z]\w*')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(7, 22), match='Mr. Peter Johns'>
# <_sre.SRE_Match object; span=(142, 158), match='Mr. George Brown'>

# %%
### Print the names of the males (Mr.) in the list
### Print phone numbers
pattern = re.compile(r'(Mr|Mrs)\.?\s[A-Z]\w*\s[A-Z]\w*')
matches = pattern.finditer(str)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(7, 22), match='Mr. Peter Johns'>
# <_sre.SRE_Match object; span=(75, 90), match='Mrs. Mary Green'>
# <_sre.SRE_Match object; span=(142, 158), match='Mr. George Brown'>

# %%
urls = '''
http://www.mysite.com
https://google.com/search?q=regular+expression+in+python
https://mail.google.com/
http://rstudio.somesite.org:8787/
http://yahoo.com
'''

# %%
pattern = re.compile(r'https?://(\w+.)?\w+.(com|org)')
matches = pattern.finditer(urls)

for match in matches:
    print(match)
# Out:
# <_sre.SRE_Match object; span=(1, 22), match='http://www.mysite.com'>
# <_sre.SRE_Match object; span=(23, 41), match='https://google.com'>
# <_sre.SRE_Match object; span=(80, 103), match='https://mail.google.com'>
# <_sre.SRE_Match object; span=(105, 132), match='http://rstudio.somesite.org'>
# <_sre.SRE_Match object; span=(139, 155), match='http://yahoo.com'>

# %% [markdown]
# # Virtual environments (pipenv)
# #### Why virtual environments
# #### How to create a virtual environment
# #### Using and sharing VE
#
# <a href="https://dev.to/rosejcday/do-you-use-docker-or-virtualenv-for-python---3de4"> virtenv/pipenv </a>
#
# #### Packrat (R)

# %% [markdown]
# ---
#
#
# http://www.markbetz.net/2014/01/17/python-if-you-have-docker-do-you-need-virtualenv/
#
# # Containers (Docker)
# #### What is a virtual container?
# #### Differences between VE and containers
# #### How to generate a virutual container
# #### How to enter a container
# #### Sharing containers
#
# Ubuntu docker image:
# https://github.com/tianon/docker-brew-ubuntu-core/tree/59aa7dfef17153ecc812adbf26516675ce67e8aa/bionic
#
# https://hub.docker.com/explore/
#
# ---
# # More resources on Dockers
#
# Using Linux dev environment inside Windows10 (no virtual machine needed!)
# https://nickjanetakis.com/blog/using-wsl-and-mobaxterm-to-create-a-linux-dev-environment-on-windows
#
# Dockers for data science
# https://www.analyticsvidhya.com/blog/2017/11/reproducible-data-science-docker-for-data-science/
#
# https://github.com/sachinruk/deepschool.io/
#
# https://www.kdnuggets.com/2018/01/docker-data-science.html
